# %%
import pandas as pd
import re
from collections import Counter
pd.set_option('precision',6)

# %%
df = pd.read_pickle("../pickles/dataframe_survey_2018-01-23_enriched.pickle")

# %%
df["func"].tail() # Ensure values for func all the way through the dataframe
# Out:
# 27108    f
# 27109    n
# 27110    n
# 27111    n
# 27112    n
# Name: func, dtype: object

# %%
df.domain.value_counts()
# Out:
# tumblr                          23776
# blogspot                          566
# wordpress                         525
# co                                283
# twitter                           240
# facebook                          168
# google                             55
# livejournal                        53
# Tumblr                             29
# weebly                             27
# reddit                             27
# okcupid                            21
# TUMBLR                             20
# fanfiction                         20
# intjforum                          16
# tumbr                              16
# youtube                            13
# personalitycafe                    13
# personalityjunkie                  13
# dreamwidth                         13
# typealyzer                         12
# ovh                                12
# pointlesssites                     12
# deviantart                         12
# Twitter                            11
# fighunter                          11
# instagram                          11
# pinterest                          10
# pastebin                           10
# infpblog                           10
#                                 ...
# crevado                             1
# zachgollwitzer                      1
# socialscienceresearchfunding        1
# smallfootprintfamily                1
# maconmedia                          1
# punkrockarmywife                    1
# imo-official                        1
# techyyouth                          1
# hlmes                               1
# sasaki                              1
# fojap                               1
# professionalsoldiers                1
# louisem                             1
# sanderkuitert                       1
# stacyapadula                        1
# polyvore                            1
# paperrater                          1
# okjohn                              1
# davidchastity                       1
# sophiesumner                        1
# nickolas360                         1
# zysys                               1
# ipotential                          1
# divinelogistics                     1
# leilicia                            1
# chrisolivieri                       1
# niasimoneauthor                     1
# Blacktiediy                         1
# gardenlilie                         1
# cadence                             1
# Name: domain, Length: 876, dtype: int64

# %% [markdown]
# # Filter out English blog texts over 100 tokens

# %%
df = df[(df.tokens > 100) & 
       (df.lang == "en") &
       (df.domain.str.contains("tumblr")) |
       (df.domain.str.contains("blogspot")) |
       (df.domain.str.contains("wordpress"))]
len(df)
# Out:
# 20708

# %% [markdown]
# # Kaggle data set

# %%
# !ls ../data
# Out:
# README.md data      notebooks pickles   py

# %%
data = df[["text","func","funcatt"]]
data.columns = ["text","base_function", "directed_function"]
data.to_csv("../data/processed/blog_texts_and_cognitive_function.csv", sep=";")
print(data.directed_function.value_counts())
print(len(data))
print(data.head())
# Out:
# ni    6653
# fi    4822
# ti    3803
# ne    1938
# si    1843
# fe     677
# se     533
# te     439
# Name: directed_function, dtype: int64
# 20708
#                                                 text base_function  \
# 1  ❀*a drop of colour*❀ 1/39 next→ home ask past ...             n
# 2  Neko cool kids can't die home family daveblog ...             f
# 3  Anything... Anything Mass Effect-related Music...             t
# 5  Perpetually In Transit Perpetually In Transit ...             n
# 6  Moving on Moving on Chronicles of an Anglo/Spa...             f
#
#   directed_function
# 1                ni
# 2                fi
# 3                ti
# 5                ne
# 6                fi

# %%
len(data.text.unique())
# Out:
# 20157

# %% [markdown]
# # Filter out text and Jungian functions (S,N,T,F) only

# %%
func_text = df[["text","func"]]
func_text.head()
# Out:
#                                                 text func
# 1  ❀*a drop of colour*❀ 1/39 next→ home ask past ...    n
# 2  Neko cool kids can't die home family daveblog ...    f
# 3  Anything... Anything Mass Effect-related Music...    t
# 5  Perpetually In Transit Perpetually In Transit ...    n
# 6  Moving on Moving on Chronicles of an Anglo/Spa...    f

# %%
len(func_text[pd.isnull(func_text.func)]) # Ensure no NaN values
# Out:
# 0

# %%
def calc_word_percentages(func=None):
    if not func:
        word_prc = {}
        tot_words = 0
        cnt = Counter()
        for ix, row in df.iterrows():
            tokens = row["text"].split()
            cnt.update(tokens)
            for token in tokens:
                tot_words += 1
        for word, count in cnt.most_common(100000):
            word_prc[word] = count / tot_words
        word_prc["tokns"] = tot_words
        return word_prc
    else:
        word_prc = {}
        tot_words = 0
        cnt = Counter()
        func_df = df[df["func"] == func]
        for ix, row in func_df.iterrows():
            tokens = row["text"].split()
            cnt.update(tokens)
            for token in tokens:
                tot_words += 1
        for word, count in cnt.most_common(1000):
            word_prc[word] = count / tot_words
        word_prc["tokns"] = tot_words
        return word_prc

# %%
series_list
# Out:
# [                                        1.007487e-06
#  !                                        1.038487e-04
#  !!                                       2.913963e-05
#  !!!                                      2.100223e-05
#  !!!!                                     7.129909e-06
#  !!!!!                                    6.354919e-06
#  !!!!!!                                   2.867463e-06
#  !!!!!!!                                  2.014974e-06
#  !!!!!!!!                                 1.394982e-06
#  !!!!!!!!!                                1.084986e-06
#  !!!!!!!!!!                               6.974911e-07
#  !!!!!!!!!!!                              5.424931e-07
#  !!!!!!!!!!!!                             1.084986e-06
#  !!!!!!!!!!!!!                            6.974911e-07
#  !!!!!!!!!!!!!!                           6.974911e-07
#  !!!!!!!!!!!!!!!!!!                       3.874950e-07
#  !!!!!!!!!!!!!!!!!!!                      5.424931e-07
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!    7.749901e-07
#  !!!!?                                    1.239984e-06
#  !!!,                                     4.649940e-07
#  !!)                                      4.649940e-07
#  !!:                                      1.162485e-06
#  !)                                       1.937475e-06
#  !”                                       1.627479e-06
#  "                                        1.472481e-06
#  "And                                     4.649940e-07
#  "Don't                                   6.199921e-07
#  "I                                       5.889925e-06
#  "I'm                                     1.627479e-06
#  "I've                                    3.874950e-07
#                                               ...
#  💕                                        1.859976e-06
#  💖                                        6.974911e-07
#  💙                                        5.424931e-07
#  💚                                        4.649940e-07
#  💜                                        6.199921e-07
#  💝                                        8.524891e-07
#  💯                                        1.549980e-06
#  🔑                                        7.749901e-07
#  🔫🍭😎🌽🌸                                    5.424931e-07
#  🔮                                        4.649940e-07
#  🔷                                        7.749901e-07
#  🔸                                        3.874950e-07
#  🕐                                        7.749901e-07
#  😁                                        9.299881e-07
#  😂                                        3.022461e-06
#  😂😂                                       6.974911e-07
#  😂😂😂                                      2.479968e-06
#  😇                                        5.424931e-07
#  😉                                        7.749901e-07
#  😊                                        1.627479e-06
#  😍                                        2.789964e-06
#  😍😍                                       5.424931e-07
#  😍😍😍😍                                     4.649940e-07
#  😎                                        1.162485e-06
#  😏                                        7.749901e-07
#  😒                                        1.239984e-06
#  😭                                        1.084986e-06
#  02          0.000157
#  1           0.002926
#  1,          0.000198
#  10          0.000401
#  11          0.000284
#  12          0.000311
#  13          0.000300
#  14          0.000396
#                ...
#  you’ll      0.000108
#  you’re      0.000615
#  you’ve      0.000137
#  |           0.003540
#  ||          0.000132
#  ~           0.000128
#  ©           0.000854
#  ·           0.001037
#  »           0.000389
#  –           0.000482
#  —           0.000827
#  “           0.000189
#  “I          0.000161
#  •           0.001114
#  …           0.000098
#  ›           0.000098
#  →           0.000707
#  ↵           0.000244
#  ∙           0.000108
#  ∞           0.000215
#  ▪           0.000148
#  ▲           0.000149
#  ►           0.000211
#  ●           0.000099
#  ★           0.000201
#  ☆           0.000196
#  ♡           0.000382
#  ♥           0.000874
#  ✖           0.000118
#  ✿           0.000117
#  Name: t, Length: 1001, dtype: float64, !           0.000108
#  #           0.004750
#  #i          0.000140
#  #the        0.000094
#  %           0.000202
#  &           0.000636
#  (           0.001457
#  (1)         0.000109
#  (Source:    0.001461
#  (and        0.000111
#  (via        0.001898
#  )           0.004970
#  *           0.000141
#  +           0.001420
#  ,           0.004907
#  -           0.003440
#  -->         0.002421
#  .           0.001749
#  ...         0.000101
#  /           0.002856
#  //          0.000798
#  0           0.000236
#  01          0.000236
#  01,         0.000159
#  02          0.000143
#  1           0.003086
#  1,          0.000228
#  1.          0.000096
#  10          0.000426
#  11          0.000267
#                ...
#  you’ll      0.000094
#  you’re      0.000607
#  you’ve      0.000135
#  {           0.000095
#  |           0.003782
#  ||          0.000168
#  }           0.000097
#  ~           0.000094
#  ©           0.000925
#  ·           0.000995
#  »           0.000407
#  –           0.000395
#  —           0.000865
#  “           0.000182
#  “I          0.000144
#  •           0.001206
#  …           0.000105
#  →           0.000740
#  ↵           0.000242
#  ∞           0.000226
#  ▪           0.000154
#  ▲           0.000154
#  ►           0.000178
#  ●           0.000134
#  ★           0.000172
#  ☆           0.000251
#  ♡           0.000552
#  ♥           0.000889
#  ✖           0.000120
#  ✿           0.000152
#  Name: f, Length: 1001, dtype: float64]

# %%
series_list = []
for func in [None, "s", "n", "t", "f"]:
    d = calc_word_percentages(func=func)
    if func:
        series_name = func + "_s"
        series_name = pd.Series(d, name=func)
    else:
        series_name = "tot" + "_s"
        series_name = pd.Series(d, name="tot")
    series_list.append(series_name)
data = pd.concat(series_list, axis=1)
pd.to_pickle(data, "../pickles/jung_functions_word_freqs.pickle")
print(data.head(5))
# Out:
#            tot         s         n         t         f
#      0.000001       NaN       NaN       NaN       NaN
# !     0.000104  0.000096  0.000099  0.000113  0.000108
# !!    0.000029       NaN       NaN       NaN       NaN
# !!!   0.000021       NaN       NaN       NaN       NaN
# !!!!  0.000007       NaN       NaN       NaN       NaN

# %%
prc_df = pd.DataFrame(data=[series_list], index=series_list[0].index, columns=["tot_prc","s_prc","n_prc","t_prc","f_prc"])
prc_df[["s_prc","n_prc"]].head(3)
# Out:
#                                                 s_prc  \
#    !           0.000096
# #           0.005061
# #i  ...
# !   !           0.000096
# #           0.005061
# #i  ...
# !!  !           0.000096
# #           0.005061
# #i  ...
#
#                                                 n_prc
#    !           0.000099
# #           0.004635
# #i  ...
# !   !           0.000099
# #           0.004635
# #i  ...
# !!  !           0.000099
# #           0.004635
# #i  ...

# %%
series_list[0].index
# Out:
# Index(['', '!', '!!', '!!!', '!!!!', '!!!!!', '!!!!!!', '!!!!!!!', '!!!!!!!!',
#        '!!!!!!!!!',
#        ...
#        '😍', '😍😍', '😍😍😍😍', '😎', '😏', '😒', '😭', '😳', '🙌', '🙏'],
#       dtype='object', length=100001)

# %%
df["tot_prc"] = series_list[0]
df["s_prc"] = series_list[1]
df["n_prc"] = series_list[2]
df["t_prc"] = series_list[3]
df["f_prc"] = series_list[4]
df
# Out:
#                                                      url typealyzer  \
# 1                        http://adropofcolour.tumblr.com       ISFP
# 2                       http://godheadcomplex.tumblr.com       ESFP
# 3                         http://chaotikaeon2.tumblr.com       INTJ
# 5             http://perpetually-in-transit.blogspot.com       ESFP
# 6                 http://www.chocolateannie.blogspot.com       ESFP
# 10     http://museofmystery.wordpress.com/2012/08/29/...       ISTP
# 11                    http://ash-the-awesome.tumblr.com/       ISTP
# 15                  http://random-nerdy-stuff.tumblr.com       ESTP
# 16                       http://supernoondles.tumblr.com       ISFP
# 17        http://supernoondles.tumblr.com/tagged/writing       ESFP
# 18                              http://kanieu.tumblr.com       INTP
# 20         http://funnyvideosandonlinestore.blogspot.pt/       ESFJ
# 21                      http://whimsyandglee.tumblr.com/       INFP
# 25                           http://diglett.blogspot.ca/       ISTP
# 34     http://typeeve.blogspot.com/2012/09/just-felt-...       ISFP
# 35                   http://www.lilymalone.wordpress.com       ESFP
# 36             http://www.yellowsmellypaper.blogspot.in/       ISFP
# 37                      http://whimsyandglee.tumblr.com/       INFP
# 38                http://whimsyandglee.tumblr.com/page/2       ISFP
# 39                      http://whimsyandglee.tumblr.com/       ISFP
# 43                     http://sistersofmercy.tumblr.com/       ISFP
# 44                         http://nellexicon.tumblr.com/       ISTP
# 45                    http://ash-the-awesome.tumblr.com/       ISTJ
# 46                        http://hellojiggles.tumblr.com       ISFP
# 47               http://revereddesecration.wordpress.com       ISTJ
# 48            http://theleavesthataregreen.blogspot.com/       ESFP
# 49                          http://wrenrow.blogspot.com/       ESFP
# 50                          http://undeklared.tumblr.com       INTP
# 51                          http://redeclared.tumblr.com       INTP
# 52                    http://tastyfoodilove.blogspot.com       ESFP
# ...                                                  ...        ...
# 27075                    http://aquilacalais.tumblr.com/       ESTP
# 27076      http://www.tumblr.com/blog/coffeestainedsatin       ISTJ
# 27077                     http://charakajg.blogspot.com/       ESFJ
# 27078                   http://starhasarrived.tumblr.com       ESTP
# 27079                   http://starhasarrived.tumblr.com       ESTP
# 27080                         http://basemeat.tumblr.com       ESFP
# 27081                   http://starhasarrived.tumblr.com       ENTP
# 27082             http://soulpoundswolfstalks.tumblr.com       ESTP
# 27083                   http://avoidthoseeyes.tumblr.com       ESTP
# 27084                   http://starhasarrived.tumblr.com       ESTP
# 27086              http://themonochromeprince.tumblr.com       ESTP
# 27089             http://lovelylittlespitfire.tumblr.com       ENTP
# 27090       http://www.tumblr.com/blog/crazypotassium009       ISTJ
# 27093              http://dimensionalhero.wordpress.com/       INTP
# 27095                        http://pommetree.tumblr.com       ISFP
# 27097                     http://leeleeadiee.tumblr.com/       ENFP
# 27098                        http://jimlingss.tumblr.com       ESFJ
# 27099                        http://umlsonoda.tumblr.com       INTJ
# 27100              http://www.lemontreewaltz.tumblr.com/       INTP
# 27102                       http://boringbebe.tumblr.com       ESFP
# 27103              http://lesbianfeferipeixes.tumblr.com       ESFP
# 27104                   http://starhasarrived.tumblr.com       INTJ
# 27105  http://nutellaaaaa.wordpress.com/2016/02/23/50...       ISFJ
# 27106                   http://starhasarrived.tumblr.com       ENTP
# 27107                 http://averyevilunicorn.tumblr.com       ESFP
# 27108                        http://i-heksa.blogspot.com       INTJ
# 27109                 http://maltinthesky.wordpress.com/       INTP
# 27110                   http://starhasarrived.tumblr.com       INTP
# 27111             http://soulpoundswolfstalks.tumblr.com       ENFP
# 27112                   http://avoidthoseeyes.tumblr.com       ISTP
#
#              actual         e         s         t    sntf_s    sntf_n  \
# 1              INFJ  0.291281  0.787844  0.460961  0.663515  0.178565
# 2              INFP  0.883579  0.951693  0.238407  0.855921  0.046931
# 3              INTP  0.332444  0.357863  0.591322  0.147668  0.252326
# 5              ENFJ  0.944394  0.943192  0.105527  0.778825  0.051134
# 6              ENFP  0.816134  0.860018  0.051798  0.536634  0.090553
# 10             INFP  0.073352  0.850472  0.608812  0.628322  0.112762
# 11     I don't know  0.418129  0.769263  0.537529  0.495471  0.150067
# 15             ENTP  0.967408  0.985934  0.987147  0.882092  0.011472
# 16             INTP  0.183238  0.732849  0.267514  0.522277  0.192229
# 17             INTP  0.730095  0.913702  0.076379  0.711090  0.067741
# 18             INTJ  0.009344  0.034724  0.991369  0.028020  0.688265
# 20     I don't know  1.000000  0.988974  0.000002  0.000667  0.000019
# 21             INFJ  0.229983  0.411923  0.163419  0.355692  0.500991
# 25             INTP  0.213375  0.966593  0.685670  0.957552  0.034250
# 34             INFP  0.452600  0.759397  0.211686  0.584749  0.184051
# 35             ISFJ  0.754503  0.873247  0.159470  0.668950  0.099422
# 36             ENFJ  0.077578  0.712656  0.247292  0.685551  0.282552
# 37             INFJ  0.258176  0.354627  0.098613  0.296548  0.529272
# 38             INFJ  0.289626  0.724553  0.068945  0.613162  0.235571
# 39             INFJ  0.301816  0.552642  0.061481  0.444489  0.358711
# 43             INFP  0.396704  0.893745  0.437363  0.692106  0.092041
# 44             INTJ  0.226800  0.734053  0.904930  0.602718  0.220946
# 45             INTJ  0.207871  0.723166  0.900660  0.327041  0.126854
# 46             ENFP  0.488329  0.691380  0.120594  0.597697  0.268601
# 47             INTJ  0.477515  0.998361  0.951575  0.070071  0.000232
# 27093  5.699020e-02  0.054731  ...    0.003472  0.003472  0.006944  0.038194
# 27095  5.255120e-02  0.349573  ...    0.006280  0.014010  0.014010  0.011594
# 27097  3.353200e-02  0.036261  ...    0.000000  0.000000  0.025510  0.012755
# 27098  6.486960e-03  0.639071  ...    0.004036  0.008073  0.016145  0.034309
# 27099  5.960700e-02  0.824183  ...    0.012658  0.006329  0.000000  0.126582
# 27100  2.201680e-01  0.136936  ...    0.000000  0.013514  0.003378  0.010135
# 27102  2.683300e-02  0.343196  ...    0.004082  0.012245  0.016327  0.069388
# 27103  6.286520e-02  0.174858  ...    0.006974  0.023710  0.006974  0.018131
# 27104  4.111300e-01  0.032870  ...    0.007111  0.007111  0.008444  0.020889
# 27105  8.135040e-02  0.442932  ...    0.003396  0.006791  0.018676  0.022920
# 27106  4.035810e-02  0.014860  ...    0.000000  0.003820  0.005731  0.020535
# 27107  6.313840e-02  0.211784  ...    0.004854  0.007468  0.019791  0.029500
# 27108  5.861580e-01  0.231501  ...    0.000000  0.000000  0.000000  0.000000
# 27109  1.371050e-01  0.069538  ...    0.004330  0.004571  0.013471  0.023334
# 27110  2.544260e-01  0.061272  ...    0.004978  0.006361  0.011615  0.030697
# 27111  4.425660e-02  0.028599  ...    0.004545  0.013636  0.012121  0.031818
# 27112  1.547540e-01  0.072068  ...    0.007905  0.003953  0.019763  0.077075
#
#           quant tot_prc s_prc n_prc t_prc  f_prc
# 1      0.033975     NaN   NaN   NaN   NaN    NaN
# 2      0.024631     NaN   NaN   NaN   NaN    NaN
# 3      0.029772     NaN   NaN   NaN   NaN    NaN
# 5      0.031895     NaN   NaN   NaN   NaN    NaN
# 6      0.055556     NaN   NaN   NaN   NaN    NaN
# 10     0.019064     NaN   NaN   NaN   NaN    NaN
# 11     0.041199     NaN   NaN   NaN   NaN    NaN
# 15     0.004831     NaN   NaN   NaN   NaN    NaN
# 16     0.023888     NaN   NaN   NaN   NaN    NaN
# 17     0.036677     NaN   NaN   NaN   NaN    NaN
# 18     0.047423     NaN   NaN   NaN   NaN    NaN
# 20     0.000000     NaN   NaN   NaN   NaN    NaN
# 21     0.037613     NaN   NaN   NaN   NaN    NaN
# 25     0.058824     NaN   NaN   NaN   NaN    NaN
# 34     0.044118     NaN   NaN   NaN   NaN    NaN
# 35     0.035339     NaN   NaN   NaN   NaN    NaN
# 36     0.047312     NaN   NaN   NaN   NaN    NaN
# 37     0.038999     NaN   NaN   NaN   NaN    NaN
# 38     0.037130     NaN   NaN   NaN   NaN    NaN
# 39     0.041464     NaN   NaN   NaN   NaN    NaN
# 43     0.024110     NaN   NaN   NaN   NaN    NaN
# 44     0.032124     NaN   NaN   NaN   NaN    NaN
# 45     0.032258     NaN   NaN   NaN   NaN    NaN
# 46     0.040000     NaN   NaN   NaN   NaN    NaN
# 47     0.022222     NaN   NaN   NaN   NaN    NaN
# 48     0.057143     NaN   NaN   NaN   NaN    NaN
# 49     0.036866     NaN   NaN   NaN   NaN    NaN
# 50     0.051613     NaN   NaN   NaN   NaN    NaN
# 51     0.026923     NaN   NaN   NaN   NaN    NaN
# 52     0.030576     NaN   NaN   NaN   NaN    NaN
# ...         ...     ...   ...   ...   ...    ...
# 27075  0.014742     NaN   NaN   NaN   NaN    NaN
# 27076  0.036723     NaN   NaN   NaN   NaN    NaN
# 27077  0.027778     NaN   NaN   NaN   NaN    NaN
# 27078  0.023130     NaN   NaN   NaN   NaN    NaN
# 27079  0.023130     NaN   NaN   NaN   NaN    NaN
# 27080  0.035191     NaN   NaN   NaN   NaN    NaN
# 27081  0.030303     NaN   NaN   NaN   NaN    NaN
# 27082  0.018330     NaN   NaN   NaN   NaN    NaN
# 27083  0.025000     NaN   NaN   NaN   NaN    NaN
# 27084  0.039373     NaN   NaN   NaN   NaN    NaN
# 27086  0.003086     NaN   NaN   NaN   NaN    NaN
# 27089  0.041667     NaN   NaN   NaN   NaN    NaN
# 27090  0.036723     NaN   NaN   NaN   NaN    NaN
# 27093  0.031250     NaN   NaN   NaN   NaN    NaN
# 27095  0.042029     NaN   NaN   NaN   NaN    NaN
# 27097  0.053571     NaN   NaN   NaN   NaN    NaN
# 27098  0.041372     NaN   NaN   NaN   NaN    NaN
# 27099  0.006329     NaN   NaN   NaN   NaN    NaN
# 27100  0.033784     NaN   NaN   NaN   NaN    NaN
# 27102  0.030612     NaN   NaN   NaN   NaN    NaN
# 27103  0.027894     NaN   NaN   NaN   NaN    NaN
# 27104  0.025333     NaN   NaN   NaN   NaN    NaN
# 27105  0.040747     NaN   NaN   NaN   NaN    NaN
# 27106  0.017192     NaN   NaN   NaN   NaN    NaN
# 27107  0.072816     NaN   NaN   NaN   NaN    NaN
# 27108  0.000000     NaN   NaN   NaN   NaN    NaN
# 27109  0.044263     NaN   NaN   NaN   NaN    NaN
# 27110  0.047566     NaN   NaN   NaN   NaN    NaN
# 27111  0.025758     NaN   NaN   NaN   NaN    NaN
# 27112  0.015810     NaN   NaN   NaN   NaN    NaN
#
# [20708 rows x 119 columns]

# %%
data[data.tot.isna()] # Check that there are no faulty lines
# Out:
# Empty DataFrame
# Columns: [tot, s, n, t, f]
# Index: []

# %%
data
# Out:
#                                                 tot         s         n  \
#                                       1.007487e-06       NaN       NaN
# !                                      1.038487e-04  0.000096  0.000099
# !!                                     2.913963e-05       NaN       NaN
# !!!                                    2.100223e-05       NaN       NaN
# !!!!                                   7.129909e-06       NaN       NaN
# !!!!!                                  6.354919e-06       NaN       NaN
# !!!!!!                                 2.867463e-06       NaN       NaN
# !!!!!!!                                2.014974e-06       NaN       NaN
# !!!!!!!!                               1.394982e-06       NaN       NaN
# !!!!!!!!!                              1.084986e-06       NaN       NaN
# !!!!!!!!!!                             6.974911e-07       NaN       NaN
# !!!!!!!!!!!                            5.424931e-07       NaN       NaN
# !!!!!!!!!!!!                           1.084986e-06       NaN       NaN
# !!!!!!!!!!!!!                          6.974911e-07       NaN       NaN
# !!!!!!!!!!!!!!                         6.974911e-07       NaN       NaN
# !!!!!!!!!!!!!!!!!!                     3.874950e-07       NaN       NaN
# !!!!!!!!!!!!!!!!!!!                    5.424931e-07       NaN       NaN
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!  7.749901e-07       NaN       NaN
# !!!!?                                  1.239984e-06       NaN       NaN
# !!!,                                   4.649940e-07       NaN       NaN
# !!)                                    4.649940e-07       NaN       NaN
# !!:                                    1.162485e-06       NaN       NaN
# !)                                     1.937475e-06       NaN       NaN
# !”                                     1.627479e-06       NaN       NaN
# "                                      1.472481e-06       NaN       NaN
# "And                                   4.649940e-07       NaN       NaN
# "Don't                                 6.199921e-07       NaN       NaN
# "I                                     5.889925e-06       NaN       NaN
# "I'm                                   1.627479e-06       NaN       NaN
# "I've                                  3.874950e-07       NaN       NaN
# ...                                             ...       ...       ...
# 💕                                      1.859976e-06       NaN       NaN
# 💖                                      6.974911e-07       NaN       NaN
# 💙                                      5.424931e-07       NaN       NaN
# 💚                                      4.649940e-07       NaN       NaN
# 💜                                      6.199921e-07       NaN       NaN
# 💝                                      8.524891e-07       NaN       NaN
# 💯                                      1.549980e-06       NaN       NaN
# 🔑                                      7.749901e-07       NaN       NaN
# 🔫🍭😎🌽🌸                                  5.424931e-07       NaN       NaN
# 🔮                                      4.649940e-07       NaN       NaN
# 🔷                                      7.749901e-07       NaN       NaN
# 🔸                                      3.874950e-07       NaN       NaN
# 🕐                                      7.749901e-07       NaN       NaN
# 😁                                      9.299881e-07       NaN       NaN
# 😂                                      3.022461e-06       NaN       NaN
# 😂😂                                     6.974911e-07       NaN       NaN
# 😂😂😂                                    2.479968e-06       NaN       NaN
# 😇                                      5.424931e-07       NaN       NaN
# 😉                                      7.749901e-07       NaN       NaN
# 😊                                      1.627479e-06       NaN       NaN
# 😍                                      2.789964e-06       NaN       NaN
# 😍😍                                     5.424931e-07       NaN       NaN
# 😍😍😍😍                                   4.649940e-07       NaN       NaN
# 😎                                      1.162485e-06       NaN       NaN
# 😏                                      7.749901e-07       NaN       NaN
# 😒                                      1.239984e-06       NaN       NaN
# 😭                                      1.084986e-06       NaN       NaN
# 😳                                      4.649940e-07       NaN       NaN
# 🙌                                      1.007487e-06       NaN       NaN
# 🙏                                      5.424931e-07       NaN       NaN
#
#                                               t         f
#                                            NaN       NaN
# !                                      0.000113  0.000108
# !!                                          NaN       NaN
# !!!                                         NaN       NaN
# !!!!                                        NaN       NaN
# !!!!!                                       NaN       NaN
# !!!!!!                                      NaN       NaN
# !!!!!!!                                     NaN       NaN
# !!!!!!!!                                    NaN       NaN
# !!!!!!!!!                                   NaN       NaN
# !!!!!!!!!!                                  NaN       NaN
# !!!!!!!!!!!                                 NaN       NaN
# !!!!!!!!!!!!                                NaN       NaN
# !!!!!!!!!!!!!                               NaN       NaN
# !!!!!!!!!!!!!!                              NaN       NaN
# !!!!!!!!!!!!!!!!!!                          NaN       NaN
# !!!!!!!!!!!!!!!!!!!                         NaN       NaN
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!       NaN       NaN
# !!!!?                                       NaN       NaN
# !!!,                                        NaN       NaN
# !!)                                         NaN       NaN
# !!:                                         NaN       NaN
# !)                                          NaN       NaN
# !”                                          NaN       NaN
# "                                           NaN       NaN
# "And                                        NaN       NaN
# "Don't                                      NaN       NaN
# "I                                          NaN       NaN
# "I'm                                        NaN       NaN
# "I've                                       NaN       NaN
# ...                                         ...       ...
# 💕                                           NaN       NaN
# 💖                                           NaN       NaN
# 💙                                           NaN       NaN
# 💚                                           NaN       NaN
# 💜                                           NaN       NaN
# 💝                                           NaN       NaN
# 💯                                           NaN       NaN
# 🔑                                           NaN       NaN
# 🔫🍭😎🌽🌸                                       NaN       NaN
# 🔮                                           NaN       NaN
# 🔷                                           NaN       NaN
# 🔸                                           NaN       NaN
# 🕐                                           NaN       NaN
# 😁                                           NaN       NaN
# 😂                                           NaN       NaN
# 😂😂                                          NaN       NaN
# 😂😂😂                                         NaN       NaN
# 😇                                           NaN       NaN
# 😉                                           NaN       NaN
# 😊                                           NaN       NaN
# 😍                                           NaN       NaN
# 😍😍                                          NaN       NaN
# 😍😍😍😍                                        NaN       NaN
# 😎                                           NaN       NaN
# 😏                                           NaN       NaN
# 😒                                           NaN       NaN
# 😭                                           NaN       NaN
# 😳                                           NaN       NaN
# 🙌                                           NaN       NaN
# 🙏                                           NaN       NaN
#
# [100001 rows x 5 columns]

# %% [markdown]
# # Sensing vs iNtuition

# %%
data = pd.read_pickle("../pickles/jung_functions_word_freqs.pickle")

# %%
sn_df = data[["s","n","tot"]]
sn_df.head(3)
# Out:
#                s             n           tot
#             NaN           NaN  0.0000007949
# !   0.0001071096  0.0001006225  0.0001037598
# !!           NaN           NaN  0.0000265972

# %%
s_dev = []
for ix, row in sn_df.iterrows():
    s_dev.append(row["s"] - row["tot"])
s = pd.Series(s_dev, index=sn_df.index)
s = s.fillna(0)
s_df = s.to_frame(name="sDev")

n_dev = []
for ix, row in sn_df.iterrows():
    n_dev.append(row["n"] - row["tot"])
n = pd.Series(n_dev, index=sn_df.index)
n = n.fillna(0)
n_df = n.to_frame(name="nDev")

# %%
s_df[s_df.sDev > 0.0005]
# Out:
#                sDev
# #      0.0011583929
# )      0.0005867616
# ,      0.0005546446
# -->    0.0006103559
# :      0.0016770887
# ago    0.0011413999
# notes  0.0013304999

# %%
n_df[n_df.nDev > 0.0001]
# Out:
#              nDev
# I    0.0002013858
# a    0.0001199900
# and  0.0002068865
# of   0.0003435210
# the  0.0004494211

# %%
print("sn_df: {}, s_df: {}, n_df: {}".format(len(sn_df.index), len(s_df.index), len(n_df.index)))
# Out:
# sn_df: 100001, s_df: 100001, n_df: 100001

# %%
sn_df.index
# Out:
# Index(['', '!', '!!', '!!!', '!!!!', '!!!!!', '!!!!!!', '!!!!!!!', '!!!!!!!!',
#        '!!!!!!!!!',
#        ...
#        '😎', '😏', '😑', '😒', '😘', '😭', '😳', '🙂', '🙌', '🙏'],
#       dtype='object', length=100001)

# %%
s_df.index
# Out:
# Index(['', '!', '!!', '!!!', '!!!!', '!!!!!', '!!!!!!', '!!!!!!!', '!!!!!!!!',
#        '!!!!!!!!!',
#        ...
#        '😎', '😏', '😑', '😒', '😘', '😭', '😳', '🙂', '🙌', '🙏'],
#       dtype='object', length=100001)

# %%
n_df.index
# Out:
# Index(['', '!', '!!', '!!!', '!!!!', '!!!!!', '!!!!!!', '!!!!!!!', '!!!!!!!!',
#        '!!!!!!!!!',
#        ...
#        '😎', '😏', '😑', '😒', '😘', '😭', '😳', '🙂', '🙌', '🙏'],
#       dtype='object', length=100001)

# %%
df = pd.concat([sn_df.reset_index(drop=True), s_df.reset_index(drop=True), n_df.reset_index(drop=True)], axis=1)

# %%
df.index = sn_df.index
df
# Out:
#                                                   s             n  \
#                                                NaN           NaN
# !                                      0.0001071096  0.0001006225
# !!                                              NaN           NaN
# !!!                                             NaN           NaN
# !!!!                                            NaN           NaN
# !!!!!                                           NaN           NaN
# !!!!!!                                          NaN           NaN
# !!!!!!!                                         NaN           NaN
# !!!!!!!!                                        NaN           NaN
# !!!!!!!!!                                       NaN           NaN
# !!!!!!!!!!                                      NaN           NaN
# !!!!!!!!!!!                                     NaN           NaN
# !!!!!!!!!!!!                                    NaN           NaN
# !!!!!!!!!!!!!                                   NaN           NaN
# !!!!!!!!!!!!!!                                  NaN           NaN
# !!!!!!!!!!!!!!!!!!!                             NaN           NaN
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!           NaN           NaN
# !!!!?                                           NaN           NaN
# !!)                                             NaN           NaN
# !!:                                             NaN           NaN
# !"                                              NaN           NaN
# !)                                              NaN           NaN
# !”                                              NaN           NaN
# "                                               NaN           NaN
# "A                                              NaN           NaN
# "And                                            NaN           NaN
# "Are                                            NaN           NaN
# "But                                            NaN           NaN
# "Do                                             NaN           NaN
# "Don't                                          NaN           NaN
# ...                                             ...           ...
# 📚                                               NaN           NaN
# 📝                                               NaN           NaN
# 📩                                               NaN           NaN
# 📺                                               NaN           NaN
# 🔑                                               NaN           NaN
# 🔖                                               NaN           NaN
# 🔷                                               NaN           NaN
# 🕐                                               NaN           NaN
# 😀                                               NaN           NaN
# 😁                                               NaN           NaN
# 😂                                               NaN           NaN
# 😂😂                                              NaN           NaN
# 😂😂😂                                             NaN           NaN
# 😅                                               NaN           NaN
# 😆                                               NaN           NaN
# 😇                                               NaN           NaN
# 😉                                               NaN           NaN
# 😊                                               NaN           NaN
# 😍                                               NaN           NaN
# 😍😍                                              NaN           NaN
# 😎                                               NaN           NaN
# 😏                                               NaN           NaN
# 😑                                               NaN           NaN
# 😒                                               NaN           NaN
# 😘                                               NaN           NaN
# 😭                                               NaN           NaN
# 😳                                               NaN           NaN
# 🙂                                               NaN           NaN
# 🙌                                               NaN           NaN
# 🙏                                               NaN           NaN
#
#                                                 tot          sDev  \
#                                       0.0000007949  0.0000000000
# !                                      0.0001037598  0.0000033498
# !!                                     0.0000265972  0.0000000000
# !!!                                    0.0000191378  0.0000000000
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!  0.0000000000
# !!!!?                                  0.0000000000
# !!)                                    0.0000000000
# !!:                                    0.0000000000
# !"                                     0.0000000000
# !)                                     0.0000000000
# !”                                     0.0000000000
# "                                      0.0000000000
# "A                                     0.0000000000
# "And                                   0.0000000000
# "Are                                   0.0000000000
# "But                                   0.0000000000
# "Do                                    0.0000000000
# "Don't                                 0.0000000000
# ...                                             ...
# 📚                                      0.0000000000
# 📝                                      0.0000000000
# 📩                                      0.0000000000
# 📺                                      0.0000000000
# 🔑                                      0.0000000000
# 🔖                                      0.0000000000
# 🔷                                      0.0000000000
# 🕐                                      0.0000000000
# 😀                                      0.0000000000
# 😁                                      0.0000000000
# 😂                                      0.0000000000
# 😂😂                                     0.0000000000
# 😂😂😂                                    0.0000000000
# 😅                                      0.0000000000
# 😆                                      0.0000000000
# 😇                                      0.0000000000
# 😉                                      0.0000000000
# 😊                                      0.0000000000
# 😍                                      0.0000000000
# 😍😍                                     0.0000000000
# 😎                                      0.0000000000
# 😏                                      0.0000000000
# 😑                                      0.0000000000
# 😒                                      0.0000000000
# 😘                                      0.0000000000
# 😭                                      0.0000000000
# 😳                                      0.0000000000
# 🙂                                      0.0000000000
# 🙌                                      0.0000000000
# 🙏                                      0.0000000000
#
# [100001 rows x 5 columns]

# %%
sn_df
# Out:
#                                                   s             n  \
#                                                NaN           NaN
# !                                      0.0001071096  0.0001006225
# !!                                              NaN           NaN
# !!!                                             NaN           NaN
# !!!!                                            NaN           NaN
# !!!!!                                           NaN           NaN
# !!!!!!                                          NaN           NaN
# !!!!!!!                                         NaN           NaN
# !!!!!!!!                                        NaN           NaN
# !!!!!!!!!                                       NaN           NaN
# !!!!!!!!!!                                      NaN           NaN
# !!!!!!!!!!!                                     NaN           NaN
# !!!!!!!!!!!!                                    NaN           NaN
# !!!!!!!!!!!!!                                   NaN           NaN
# !!!!!!!!!!!!!!                                  NaN           NaN
# !!!!!!!!!!!!!!!!!!!                             NaN           NaN
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!           NaN           NaN
# !!!!?                                           NaN           NaN
# !!)                                             NaN           NaN
# !!:                                             NaN           NaN
# !"                                              NaN           NaN
# !)                                              NaN           NaN
# !”                                              NaN           NaN
# "                                               NaN           NaN
# "A                                              NaN           NaN
# "And                                            NaN           NaN
# "Are                                            NaN           NaN
# "But                                            NaN           NaN
# "Do                                             NaN           NaN
# "Don't                                          NaN           NaN
# ...                                             ...           ...
# 📚                                               NaN           NaN
# 📝                                               NaN           NaN
# 📩                                               NaN           NaN
# 📺                                               NaN           NaN
# 🔑                                               NaN           NaN
# 🔖                                               NaN           NaN
# 🔷                                               NaN           NaN
# 🕐                                               NaN           NaN
# 😀                                               NaN           NaN
# 😁                                               NaN           NaN
# 😂                                               NaN           NaN
# 😂😂                                              NaN           NaN
# 😂😂😂                                             NaN           NaN
# 😅                                               NaN           NaN
# 😆                                               NaN           NaN
# 😇                                               NaN           NaN
# 😉                                               NaN           NaN
# 😊                                               NaN           NaN
# 😍                                               NaN           NaN
# 😍😍                                              NaN           NaN
# 😎                                               NaN           NaN
# 😏                                               NaN           NaN
# 😑                                               NaN           NaN
# 😒                                               NaN           NaN
# 😘                                               NaN           NaN
# 😭                                               NaN           NaN
# 😳                                               NaN           NaN
# 🙂                                               NaN           NaN
# 🙌                                               NaN           NaN
# 🙏                                               NaN           NaN
#
#                                                 tot
#                                       0.0000007949
# !                                      0.0001037598
# !!                                     0.0000265972
# !!!                                    0.0000191378
# !!!!                                   0.0000064812
# !!!!!                                  0.0000052583
# !!!!!!                                 0.0000023234
# !!!!!!!                                0.0000018954
# !!!!!!!!                               0.0000011617
# !!!!!!!!!                              0.0000009783
# !!!!!!!!!!                             0.0000005503
# !!!!!!!!!!!                            0.0000004280
# !!!!!!!!!!!!                           0.0000008560
# !!!!!!!!!!!!!                          0.0000005503
# !!!!!!!!!!!!!!                         0.0000006726
# !!!!!!!!!!!!!!!!!!!                    0.0000004280
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!  0.0000007337
# !!!!?                                  0.0000009783
# !!)                                    0.0000004280
# !!:                                    0.0000009171
# !"                                     0.0000004280
# !)                                     0.0000018954
# !”                                     0.0000014674
# "                                      0.0000111280
# "A                                     0.0000007337
# "And                                   0.0000005503
# "Are                                   0.0000004280
# "But                                   0.0000004891
# "Do                                    0.0000006726
# "Don't                                 0.0000008560
# ...                                             ...
# 📚                                      0.0000004280
# 📝                                      0.0000027514
# 📩                                      0.0000027514
# 📺                                      0.0000005503
# 🔑                                      0.0000006114
# 🔖                                      0.0000018343
# 🔷                                      0.0000006114
# 🕐                                      0.0000006114
# 😀                                      0.0000014063
# 😁                                      0.0000007337
# 😂                                      0.0000037909
# 😂😂                                     0.0000006726
# 😂😂😂                                    0.0000026292
# 😅                                      0.0000006726
# 😆                                      0.0000004891
# 😇                                      0.0000004280
# 😉                                      0.0000010394
# 😊                                      0.0000015897
# 😍                                      0.0000030572
# 😍😍                                     0.0000004891
# 😎                                      0.0000009783
# 😏                                      0.0000007949
# 😑                                      0.0000007337
# 😒                                      0.0000010394
# 😘                                      0.0000004891
# 😭                                      0.0000011617
# 😳                                      0.0000004280
# 🙂                                      0.0000014674
# 🙌                                      0.0000009171
# 🙏                                      0.0000004891
#
# [100001 rows x 3 columns]

# %%
n.index
# Out:
# Index(['', '!', '!!', '!!!', '!!!!', '!!!!!', '!!!!!!', '!!!!!!!', '!!!!!!!!',
#        '!!!!!!!!!',
#        ...
#        '😎', '😏', '😑', '😒', '😘', '😭', '😳', '🙂', '🙌', '🙏'],
#       dtype='object', length=100001)

# %%
sn_df.index
# Out:
# Index(['', '!', '!!', '!!!', '!!!!', '!!!!!', '!!!!!!', '!!!!!!!', '!!!!!!!!',
#        '!!!!!!!!!',
#        ...
#        '😎', '😏', '😑', '😒', '😘', '😭', '😳', '🙂', '🙌', '🙏'],
#       dtype='object', length=100001)
