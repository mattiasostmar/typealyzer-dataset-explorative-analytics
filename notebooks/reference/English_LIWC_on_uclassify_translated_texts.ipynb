# %% [raw]
# From: James W Pennebaker <pennebaker@utexas.edu>
# Date: Sun, 22 Oct 2017 12:31:02 -0500
# Message-ID: <CAG7SFVLeni2MiOb7AJNzB3K7zx==5WXs36DMMkDJA6Cd=pYK+Q@mail.gmail.com>
# Subject: Re: A writing tool for healing trauma in children from warzones?
# To: "Mattias Östmar" <mattiasostmar@gmail.com>
# Content-Type: multipart/alternative; boundary="94eb2c07720ee7257e055c2611cc"
#
# --94eb2c07720ee7257e055c2611cc
# Content-Type: text/plain; charset="UTF-8"
# Content-Transfer-Encoding: quoted-printable
#
# Mattias--
# Although difficult to do, you could always automatically put the Swedish
# samples through Google Translate and then use the English LIWC to analyze
# them. I've found this to work quite well since Google Translate does a fine
# job at translating function and other common words -- which are at the
# heart of LIWC.
#
# It's better than nothing.
#
# Jamie

# %%
import os
import requests
import json
import re
import pickle
import random
import pandas as pd
from collections import Counter

# %%
os.environ["UCLASSIFY_KEY"]
# Out:
# '2B8UweHuLT5ZD4ez6kFdMFkBVqA='

# %%
a_text = """
She's mine. I adore her. No matter what I will always love her - my special honey!
Idag har jag varit tio år på Twitter. 232987 tweets. 14715 följare. Vunnit Sveriges meste Twittrare 2009. Idag är min average 87 tweets per dag. Den var mycket högre förut. Twitter har gett mig en massa bra. En massa jobb, mängder av vänner (och en del fiender), stor kunskap.

Det bästa är att Twitter gav mig min bästa vän och min kompanjon Sarah aka @sanasilb. Hon betyder oerhört mycket. Tacksam för att hon började stalka mig våren 2010.

Livet hade helt klart sett annorlunda ut utan Twitter även om de senaste åren har inneburit mindre twittrande eftersom jag helt enkelt inte riktigt längre känner mig hemma där. Det är annorlunda. Det är mer broadcast. Och även om jag gillar algoritmerna på Instagram och Facebook så ogillar jag hur den implementerats på Twitter. Samtidigt som jag ogillar Tweetbot så jag kommer liksom inte undan den.

Tio år till? Om Twitter finns kvar. För Facebook, Twitter, Instagram är en del av min vardag. Snapchat lyckades inte ta den platsen. Linkedin inte fullt så.
"""

# %%
def translate_from_sv_to_en(list_of_texts):
    header = {"Content-Type": "application/json"}
    data = {"key":os.environ["UCLASSIFY_KEY"], 
            "source":"sv", 
            "target":"en", 
            "t":list_of_texts}
    result = requests.post("https://language.uclassify.com/translate/v1/",
                       json = data,
                       headers = header)

    return result.json()

# %%
def load_liwc_dic_file_into_word_and_cats_dicts():
    cats = pickle.load(open("liwc_2007_cats_dict.pickle","rb"))
    words = pickle.load(open("liwc_2007_words_dict.pickle","rb"))
    
    category_names = []
    for key in cats.keys():
        category_names.append(cats[key])
    
    return cats, words, category_names

# %%
def detect_language(list_of_texts):
    """
    Sends a list of strings to uClassify's language-detector classifier and returns languages classifications.
    
    :param list_of_texts: list of strings to detect language of.
    :return: list of classification result dicts for each string in input list.
    """
    header = {"Content-Type":"application/json",
         "Authorization": "Token "+os.environ["UCLASSIFY_KEY"]}
    
    data = {"texts":list_of_texts}

    res = requests.post("https://api.uclassify.com/v1/uclassify/language-detector/classify", headers=header, json=data)

    return res.json()

# %%
def separate_punctuation_with_whitespace(original_string):
   return re.sub(r"([\w/'+$\s-]+|[^\w/'+$\s-]+)\s*", r"\1 ", original_string) # todo: not perfect - leaves "),"

# %%
def liwc_analysis_on_english_string(original_string, words):
    """
    Takes a string and returns word frequencies according to (most of) LIWC 2007.
    
    :param original_string: string representing the input text with no transformations.
    :param words: dictionary containing categories as keys with 0.0 as values plus "WC" = word count.
    :return: dictionary containg LIWC 2007 categories minus the psychological summary variables. 
    """ 
    liwc = dict.fromkeys(category_names, 0.0)
    punct_token_text = separate_punctuation_with_whitespace(paragraphs[para_cnt])
    liwc["WC"] = len(punct_token_text.split())

    for word in words:
        regex_word = re.sub(r"\*",r"\w+",word) # 'cousin*' in .dic file transformed into 'cousin\w+'
        word_patt = re.compile(regex_word)
        
        if word_patt.search(original_string):
            matches = word_patt.findall(original_string)
            print("word: {}".format(word))
            print("cat numbers: {}".format(words[word]))
            for cat_no in words[word]:
                if liwc.get(cats[cat_no]):
                    liwc[cats[cat_no]] += (len(matches) / liwc["WC"])   
                else:
                    liwc[cats[cat_no]] = (len(matches) / liwc["WC"])
    
    return liwc

# %%
paragraphs = [paragraph for paragraph in a_text.split("\n") if not paragraph == ""]
print(paragraphs)
print()

cats, words, category_names = transform_liwc_dic_file_into_word_and_cats_dicts()
    
res_list = detect_language(paragraphs)

swedish_texts_indices_to_translate = []
    
para_cnt = 0
for index, res_dict in enumerate(res_list): # i.e. for each text we've sent to uClassify language-detector classifier
    para_cnt = index
    print("paragraphs index: {}".format(para_cnt))
    print("textCoverage: {}".format(res_dict["textCoverage"]))
    
    max_class = {"className":"dummy", "p":0.0}
    for class_res in res_dict["classification"]:
        if class_res["p"] > max_class["p"]:
            max_class = class_res
    print(max_class)

    if max_class["className"] == "English_eng":
        the_text = paragraphs[para_cnt]
        print(the_text)
        
        result = liwc_analysis_on_english_string(the_text, words)
        print(result)
        
    elif max_class["className"] == "Swedish_swe":
        swedish_texts_indices_to_translate.append(para_cnt)
        
    else:
        print("Skipping the following text, since it appears not be lang en or sv:\n{}".format(paragraphs[para_cnt]))
    print()
    
swedish_full_texts_to_translate = []
for ix, para in enumerate(paragraphs):
    if ix in swedish_texts_indices_to_translate:
        swedish_full_texts_to_translate.append(paragraphs[ix])
        
print("swedish_texts_indices_to_translate: {}".format(swedish_texts_indices_to_translate))
translation_results = translate_from_sv_to_en(swedish_full_texts_to_translate) 
for ix, text in enumerate(translation_results["translations"]):
    liwc_result = liwc_analysis_on_english_string(text, words)
    print("Text:\n{}\nLiwc:\n{}".format(text, liwc_result))
    print()
# Out:
# ["She's mine. I adore her. No matter what I will always love her - my special honey!", 'Idag har jag varit tio år på Twitter. 232987 tweets. 14715 följare. Vunnit Sveriges meste Twittrare 2009. Idag är min average 87 tweets per dag. Den var mycket högre förut. Twitter har gett mig en massa bra. En massa jobb, mängder av vänner (och en del fiender), stor kunskap.', 'Det bästa är att Twitter gav mig min bästa vän och min kompanjon Sarah aka @sanasilb. Hon betyder oerhört mycket. Tacksam för att hon började stalka mig våren 2010.', 'Livet hade helt klart sett annorlunda ut utan Twitter även om de senaste åren har inneburit mindre twittrande eftersom jag helt enkelt inte riktigt längre känner mig hemma där. Det är annorlunda. Det är mer broadcast. Och även om jag gillar algoritmerna på Instagram och Facebook så ogillar jag hur den implementerats på Twitter. Samtidigt som jag ogillar Tweetbot så jag kommer liksom inte undan den.', 'Tio år till? Om Twitter finns kvar. För Facebook, Twitter, Instagram är en del av min vardag. Snapchat lyckades inte ta den platsen. Linkedin inte fullt så.']
#
# paragraphs index: 0
# textCoverage: 1.0
# {'className': 'English_eng', 'p': 1.0}
# She's mine. I adore her. No matter what I will always love her - my special honey!
# word: love
# cat numbers: ['11', '14', '125', '126', '146', '149', '121']
# word: at
# cat numbers: ['1', '17', '252', '250']
# word: or
# cat numbers: ['1', '18', '131', '135', '139']
# word: i
# cat numbers: ['1', '2', '3', '4']
# word: will
# cat numbers: ['11', '1', '12', '15']
# word: er
# cat numbers: ['463']
# word: ma
# cat numbers: ['121', '122']
# word: ho
# cat numbers: ['146', '149']
# word: special
# cat numbers: ['125', '126']
# word: do
# cat numbers: ['11', '1', '12', '14']
# word: one
# cat numbers: ['1', '21']
# word: on
# cat numbers: ['1', '17', '252', '250']
# word: ha
# cat numbers: ['125', '126', '462']
# word: way
# cat numbers: ['250']
# word: my
# cat numbers: ['1', '2', '3', '4']
# word: ill
# cat numbers: ['146', '148']
# word: a
# cat numbers: ['1', '10']
# word: mine
# cat numbers: ['1', '2', '3', '4']
# word: what
# cat numbers: ['1', '2', '9']
# word: min
# cat numbers: ['253', '250']
# word: he
# cat numbers: ['1', '2', '3', '7', '121']
# word: her
# cat numbers: ['1', '2', '3', '7', '121']
# word: in
# cat numbers: ['1', '17', '252', '250']
# word: he's
# cat numbers: ['1', '2', '3', '7', '11', '12', '14', '121']
# word: always
# cat numbers: ['131', '136', '253', '250']
# word: honey
# cat numbers: ['121', '123', '140']
# word: ador*
# cat numbers: ['125', '126']
# {'excl': 0.05, 'space': 0.2, 'health': 0.05, 'negate': 0.0, 'social': 0.44999999999999996, 'friend': 0.05, 'humans': 0.0, 'family': 0.05, 'nonfl': 0.15, 'quant': 0.0, 'pronoun': 0.6, 'you': 0.0, 'percept': 0.05, 'shehe': 0.3, 'posemo': 0.2, 'funct': 1.3000000000000003, 'present': 0.15000000000000002, 'filler': 0.0, 'death': 0.0, 'see': 0.0, 'past': 0.0, 'ingest': 0.0, 'ppron': 0.55, 'relativ': 0.35, 'ipron': 0.05, 'feel': 0.0, 'insight': 0.0, 'cogmech': 0.1, 'tentat': 0.05, 'body': 0.0, 'i': 0.25, 'time': 0.1, 'swear': 0.0, 'motion': 0.0, 'future': 0.05, 'home': 0.0, 'leisure': 0.0, 'anx': 0.0, 'money': 0.0, 'article': 0.3, 'discrep': 0.0, 'they': 0.0, 'cause': 0.0, 'sexual': 0.1, 'hear': 0.0, 'negemo': 0.0, 'we': 0.0, 'assent': 0.05, 'preps': 0.2, 'WC': 20, 'adverb': 0.0, 'sad': 0.0, 'number': 0.05, 'conj': 0.05, 'inhib': 0.0, 'bio': 0.15000000000000002, 'relig': 0.0, 'auxverb': 0.15000000000000002, 'incl': 0.0, 'verb': 0.2, 'certain': 0.05, 'anger': 0.0, 'affect': 0.2, 'work': 0.0, 'achieve': 0.0}
#
# paragraphs index: 1
# textCoverage: 0.99537
# {'className': 'Swedish_swe', 'p': 1.0}
#
# paragraphs index: 2
# textCoverage: 0.972222
# {'className': 'Swedish_swe', 'p': 1.0}
#
# paragraphs index: 3
# textCoverage: 0.987842
# {'className': 'Swedish_swe', 'p': 1.0}
#
# paragraphs index: 4
# textCoverage: 0.985816
# {'className': 'Swedish_swe', 'p': 1.0}
#
# swedish_texts_indices_to_translate: [1, 2, 3, 4]
# word: before
# cat numbers: ['1', '17', '253', '250']
# word: ends
# cat numbers: ['253', '250']
# word: at
# cat numbers: ['1', '17', '252', '250']
# word: or
# cat numbers: ['1', '18', '131', '135', '139']
# word: i
# cat numbers: ['1', '2', '3', '4']
# word: ears
# cat numbers: ['140', '142', '146', '147']
# word: an
# cat numbers: ['1', '10']
# word: given
# cat numbers: ['11', '13']
# word: hi
# cat numbers: ['121']
# word: it
# cat numbers: ['1', '2', '9']
# word: er
# cat numbers: ['463']
# word: wed
# cat numbers: ['121']
# word: go
# cat numbers: ['11', '14', '251', '250']
# word: is
# cat numbers: ['11', '1', '12', '14']
# word: low*
# cat numbers: ['125', '127', '130', '252', '250']
# word: have
# cat numbers: ['11', '1', '12', '14']
# word: od
# cat numbers: ['360']
# word: lot
# cat numbers: ['1', '20', '131', '135']
# word: now
# cat numbers: ['1', '16', '253', '250']
# word: iv
# cat numbers: ['146', '148']
# word: on
# cat numbers: ['1', '17', '252', '250']
# word: ha
# cat numbers: ['125', '126', '462']
# word: good
# cat numbers: ['125', '126']
# word: end
# cat numbers: ['253', '250']
# word: my
# cat numbers: ['1', '2', '3', '4']
# word: a
# cat numbers: ['1', '10']
# word: friend*
# cat numbers: ['121', '123', '125', '126']
# word: owe
# cat numbers: ['11', '14', '358']
# word: know
# cat numbers: ['11', '14', '131', '132']
# word: lots
# cat numbers: ['1', '20', '131', '135']
# word: been
# cat numbers: ['11', '1', '12', '13']
# word: ye
# cat numbers: ['1', '2', '3', '6', '121']
# word: eat
# cat numbers: ['146', '150']
# word: high
# cat numbers: ['252', '250']
# word: age
# cat numbers: ['253', '250']
# word: ten
# cat numbers: ['1', '21']
# word: ive
# cat numbers: ['1', '2', '3', '4', '11', '12', '14']
# word: and
# cat numbers: ['1', '18', '131', '138']
# word: knowledg*
# cat numbers: ['131', '132']
# word: as
# cat numbers: ['1', '17', '18']
# word: year
# cat numbers: ['253', '250']
# word: he
# cat numbers: ['1', '2', '3', '7', '121']
# word: her
# cat numbers: ['1', '2', '3', '7', '121']
# word: has
# cat numbers: ['11', '1', '12', '14']
# word: work
# cat numbers: ['354', '355']
# word: great
# cat numbers: ['125', '126']
# word: much
# cat numbers: ['1', '20']
# word: of
# cat numbers: ['1', '17']
# word: give
# cat numbers: ['11', '14', '121']
# word: highe*
# cat numbers: ['252', '250']
# word: follow
# cat numbers: ['11', '14', '251', '250']
# word: we
# cat numbers: ['1', '2', '3', '5', '121', '131', '138']
# word: most
# cat numbers: ['1', '20', '131', '135']
# word: edge
# cat numbers: ['252', '250', '140', '143']
# word: no
# cat numbers: ['1', '19']
# word: are
# cat numbers: ['11', '1', '12', '14']
# word: me
# cat numbers: ['1', '2', '3', '4']
# word: ear
# cat numbers: ['140', '142', '146', '147']
# word: led
# cat numbers: ['131', '133', '251', '250']
# word: enemie*
# cat numbers: ['121', '125', '127', '129']
# word: years
# cat numbers: ['253', '250']
# word: for
# cat numbers: ['1', '17']
# word: yea
# cat numbers: ['462']
# word: den
# cat numbers: ['357']
# word: be
# cat numbers: ['11', '1', '12']
# word: gre
# cat numbers: ['354']
# word: was
# cat numbers: ['11', '1', '12', '13']
# Text:
# Today i have been ten years on twitter. 232987 tweets. 14715 follower. Won Sweden most Twittrare 2009. Today is my ave rage 87 tweets per day. It was much higher before. Twitter has given me a lot of good. A lot of work, lots of friends (and a few enemies), great knowledge.
# Liwc:
# {'excl': 0.058823529411764705, 'space': 0.2058823529411765, 'health': 0.029411764705882353, 'negate': 0.029411764705882353, 'social': 0.35294117647058826, 'friend': 0.029411764705882353, 'humans': 0.0, 'family': 0.0, 'nonfl': 0.14705882352941177, 'quant': 0.17647058823529413, 'pronoun': 0.6470588235294118, 'you': 0.029411764705882353, 'percept': 0.08823529411764705, 'shehe': 0.058823529411764705, 'posemo': 0.14705882352941177, 'funct': 1.970588235294116, 'present': 0.29411764705882354, 'filler': 0.0, 'death': 0.08823529411764706, 'see': 0.0, 'past': 0.08823529411764705, 'ingest': 0.029411764705882353, 'ppron': 0.5588235294117647, 'relativ': 0.5, 'ipron': 0.08823529411764706, 'feel': 0.029411764705882353, 'insight': 0.058823529411764705, 'cogmech': 0.4411764705882353, 'tentat': 0.2058823529411765, 'body': 0.058823529411764705, 'i': 0.35294117647058826, 'time': 0.2058823529411765, 'swear': 0.0, 'motion': 0.08823529411764705, 'future': 0.0, 'home': 0.029411764705882353, 'leisure': 0.0, 'anx': 0.0, 'money': 0.029411764705882353, 'article': 0.4411764705882353, 'discrep': 0.0, 'they': 0.0, 'cause': 0.029411764705882353, 'sexual': 0.0, 'hear': 0.058823529411764705, 'negemo': 0.058823529411764705, 'we': 0.11764705882352941, 'assent': 0.08823529411764705, 'preps': 0.29411764705882354, 'WC': 34, 'adverb': 0.029411764705882353, 'sad': 0.029411764705882353, 'number': 0.029411764705882353, 'conj': 0.14705882352941174, 'inhib': 0.0, 'bio': 0.11764705882352941, 'relig': 0.0, 'auxverb': 0.2647058823529412, 'incl': 0.14705882352941177, 'verb': 0.44117647058823534, 'certain': 0.0, 'anger': 0.029411764705882353, 'affect': 0.2058823529411765, 'work': 0.058823529411764705, 'achieve': 0.029411764705882353}
#
# word: us
# cat numbers: ['1', '2', '3', '5', '121']
# word: at
# cat numbers: ['1', '17', '252', '250']
# word: means
# cat numbers: ['11', '14', '131', '132']
# word: or
# cat numbers: ['1', '18', '131', '135', '139']
# word: i
# cat numbers: ['1', '2', '3', '4']
# word: ring
# cat numbers: ['140', '142']
# word: spring
# cat numbers: ['253', '250']
# word: ah
# cat numbers: ['462']
# word: mean
# cat numbers: ['11', '14', '131', '132']
# word: an
# cat numbers: ['1', '10']
# word: ate
# cat numbers: ['11', '13', '146', '150']
# word: gave
# cat numbers: ['11', '13', '121']
# word: it
# cat numbers: ['1', '2', '9']
# word: er
# cat numbers: ['463']
# word: best
# cat numbers: ['125', '126', '355', '1', '20']
# word: ma
# cat numbers: ['121', '122']
# word: is
# cat numbers: ['11', '1', '12', '14']
# word: nor
# cat numbers: ['1', '18', '19']
# word: began
# cat numbers: ['11', '13', '253', '250']
# word: ha
# cat numbers: ['125', '126', '462']
# word: pa
# cat numbers: ['121', '122']
# word: part
# cat numbers: ['1', '20']
# word: end
# cat numbers: ['253', '250']
# word: that
# cat numbers: ['1', '2', '9']
# word: my
# cat numbers: ['1', '2', '3', '4']
# word: a
# cat numbers: ['1', '10']
# word: and
# cat numbers: ['1', '18', '131', '138']
# word: as
# cat numbers: ['1', '17', '18']
# word: he
# cat numbers: ['1', '2', '3', '7', '121']
# word: in
# cat numbers: ['1', '17', '252', '250']
# word: she
# cat numbers: ['1', '2', '3', '7', '121']
# word: no
# cat numbers: ['1', '19']
# word: to
# cat numbers: ['1', '17']
# word: art
# cat numbers: ['356']
# word: me
# cat numbers: ['1', '2', '3', '4']
# word: enorm*
# cat numbers: ['252', '250']
# word: be
# cat numbers: ['11', '1', '12']
# Text:
# It is best to Twitter gave me my best friend and my partner Sarah aka @sanasilb. She means enormously. Grateful that she began loma me spring 2010.
# Liwc:
# {'excl': 0.029411764705882353, 'space': 0.11764705882352941, 'health': 0.0, 'negate': 0.058823529411764705, 'social': 0.20588235294117646, 'friend': 0.0, 'humans': 0.0, 'family': 0.058823529411764705, 'nonfl': 0.058823529411764705, 'quant': 0.08823529411764705, 'pronoun': 0.4705882352941177, 'you': 0.0, 'percept': 0.029411764705882353, 'shehe': 0.08823529411764705, 'posemo': 0.08823529411764705, 'funct': 1.4705882352941169, 'present': 0.08823529411764705, 'filler': 0.0, 'death': 0.0, 'see': 0.0, 'past': 0.08823529411764705, 'ingest': 0.029411764705882353, 'ppron': 0.411764705882353, 'relativ': 0.2058823529411765, 'ipron': 0.058823529411764705, 'feel': 0.0, 'insight': 0.058823529411764705, 'cogmech': 0.11764705882352941, 'tentat': 0.029411764705882353, 'body': 0.0, 'i': 0.29411764705882354, 'time': 0.08823529411764705, 'swear': 0.0, 'motion': 0.0, 'future': 0.0, 'home': 0.0, 'leisure': 0.029411764705882353, 'anx': 0.0, 'money': 0.0, 'article': 0.5294117647058824, 'discrep': 0.0, 'they': 0.0, 'cause': 0.0, 'sexual': 0.0, 'hear': 0.029411764705882353, 'negemo': 0.0, 'we': 0.029411764705882353, 'assent': 0.058823529411764705, 'preps': 0.14705882352941177, 'WC': 34, 'adverb': 0.0, 'sad': 0.0, 'number': 0.0, 'conj': 0.11764705882352941, 'inhib': 0.0, 'bio': 0.029411764705882353, 'relig': 0.0, 'auxverb': 0.11764705882352941, 'incl': 0.029411764705882353, 'verb': 0.2647058823529412, 'certain': 0.0, 'anger': 0.0, 'affect': 0.08823529411764705, 'work': 0.0, 'achieve': 0.058823529411764705}
#
# word: all
# cat numbers: ['1', '20', '131', '136']
# word: us
# cat numbers: ['1', '2', '3', '5', '121']
# word: im
# cat numbers: ['1', '2', '3', '4', '11', '12', '14']
# word: men
# cat numbers: ['121', '124']
# word: early
# cat numbers: ['253', '250']
# word: at
# cat numbers: ['1', '17', '252', '250']
# word: or
# cat numbers: ['1', '18', '131', '135', '139']
# word: eve
# cat numbers: ['253', '250']
# word: if
# cat numbers: ['1', '18', '131', '134', '135', '139']
# word: i
# cat numbers: ['1', '2', '3', '4']
# word: longe*
# cat numbers: ['253', '250']
# word: had
# cat numbers: ['11', '1', '12', '13']
# word: without
# cat numbers: ['1', '17', '19', '131', '139']
# word: how
# cat numbers: ['1', '16', '18', '131', '133']
# word: broad*
# cat numbers: ['252', '250']
# word: hey
# cat numbers: ['121']
# word: ears
# cat numbers: ['140', '142', '146', '147']
# word: the
# cat numbers: ['1', '10']
# word: more
# cat numbers: ['1', '20']
# word: thou
# cat numbers: ['1', '2', '3', '6', '121']
# word: not
# cat numbers: ['1', '19', '131', '139']
# word: mean
# cat numbers: ['11', '14', '131', '132']
# word: am
# cat numbers: ['11', '1', '12', '14']
# word: will
# cat numbers: ['11', '1', '12', '15']
# word: an
# cat numbers: ['1', '10']
# word: really
# cat numbers: ['1', '16', '131', '139']
# word: like
# cat numbers: ['125', '126', '253', '464']
# word: hi
# cat numbers: ['121']
# word: real
# cat numbers: ['131', '136']
# word: it
# cat numbers: ['1', '2', '9']
# word: er
# cat numbers: ['463']
# word: road*
# cat numbers: ['252', '250']
# word: go
# cat numbers: ['11', '14', '251', '250']
# word: ho
# cat numbers: ['146', '149']
# word: is
# cat numbers: ['11', '1', '12', '14']
# word: they
# cat numbers: ['1', '2', '3', '8', '121']
# word: use
# cat numbers: ['11', '14', '131', '133']
# word: feel
# cat numbers: ['11', '14', '131', '132', '140', '143']
# word: long
# cat numbers: ['253', '250']
# word: simply
# cat numbers: ['1', '16']
# word: clearly
# cat numbers: ['1', '16', '131', '136']
# word: on
# cat numbers: ['1', '17', '252', '250']
# word: dislike
# cat numbers: ['11', '14', '125', '127']
# word: so
# cat numbers: ['1', '16', '18']
# word: meant
# cat numbers: ['11', '13', '131', '132']
# word: with
# cat numbers: ['1', '17', '131', '138']
# word: ha
# cat numbers: ['125', '126', '462']
# word: hm*
# cat numbers: ['462', '463']
# word: seen
# cat numbers: ['11', '13', '140', '141']
# word: ill
# cat numbers: ['146', '148']
# word: because
# cat numbers: ['1', '18', '131', '133']
# word: a
# cat numbers: ['1', '10']
# word: less
# cat numbers: ['1', '20']
# word: ye
# cat numbers: ['1', '2', '3', '6', '121']
# word: cent
# cat numbers: ['358']
# word: ace
# cat numbers: ['355']
# word: out
# cat numbers: ['1', '17', '131', '138', '252', '250']
# word: and
# cat numbers: ['1', '18', '131', '138']
# word: bro
# cat numbers: ['121', '122']
# word: as
# cat numbers: ['1', '17', '18']
# word: year
# cat numbers: ['253', '250']
# word: home
# cat numbers: ['357']
# word: he
# cat numbers: ['1', '2', '3', '7', '121']
# word: her
# cat numbers: ['1', '2', '3', '7', '121']
# word: has
# cat numbers: ['11', '1', '12', '14']
# word: in
# cat numbers: ['1', '17', '252', '250']
# word: clear
# cat numbers: ['131', '136']
# word: ok
# cat numbers: ['125', '126', '462']
# word: even
# cat numbers: ['1', '16']
# word: there
# cat numbers: ['1', '16']
# word: we
# cat numbers: ['1', '2', '3', '5', '121', '131', '138']
# word: no
# cat numbers: ['1', '19']
# word: caus*
# cat numbers: ['131', '133']
# word: me
# cat numbers: ['1', '2', '3', '4']
# word: ear
# cat numbers: ['140', '142', '146', '147']
# word: fee
# cat numbers: ['358']
# word: see
# cat numbers: ['11', '14', '140', '141']
# word: years
# cat numbers: ['253', '250']
# word: yea
# cat numbers: ['462']
# word: tho
# cat numbers: ['1', '16', '18']
# word: be
# cat numbers: ['11', '1', '12']
# word: here
# cat numbers: ['1', '16']
# Text:
# Life had clearly seen different without Twitter even if they recent years has meant less tweeting because i simply not really longer feel me at home there. It is different. It is more broadcast. And even if i like algorithms on Instagram and Facebook so dislike me how the implemented on twitter. Whilst i dislike Tweetbot so i will like not escape the.
# Liwc:
# {'excl': 0.3235294117647059, 'space': 0.23529411764705882, 'health': 0.029411764705882353, 'negate': 0.14705882352941174, 'social': 0.44117647058823534, 'friend': 0.0, 'humans': 0.029411764705882353, 'family': 0.029411764705882353, 'nonfl': 0.2058823529411765, 'quant': 0.08823529411764705, 'pronoun': 1.4117647058823526, 'you': 0.058823529411764705, 'percept': 0.1764705882352941, 'shehe': 0.14705882352941177, 'posemo': 0.20588235294117646, 'funct': 3.4117647058823497, 'present': 0.44117647058823534, 'filler': 0.11764705882352941, 'death': 0.0, 'see': 0.058823529411764705, 'past': 0.08823529411764705, 'ingest': 0.0, 'ppron': 1.2941176470588234, 'relativ': 0.4705882352941177, 'ipron': 0.11764705882352941, 'feel': 0.029411764705882353, 'insight': 0.08823529411764705, 'cogmech': 0.7941176470588236, 'tentat': 0.20588235294117646, 'body': 0.08823529411764705, 'i': 0.9705882352941176, 'time': 0.3235294117647059, 'swear': 0.0, 'motion': 0.029411764705882353, 'future': 0.029411764705882353, 'home': 0.029411764705882353, 'leisure': 0.0, 'anx': 0.0, 'money': 0.058823529411764705, 'article': 0.6470588235294117, 'discrep': 0.14705882352941177, 'they': 0.029411764705882353, 'cause': 0.11764705882352941, 'sexual': 0.08823529411764706, 'hear': 0.08823529411764705, 'negemo': 0.058823529411764705, 'we': 0.08823529411764705, 'assent': 0.14705882352941177, 'preps': 0.29411764705882354, 'WC': 34, 'adverb': 0.3235294117647059, 'sad': 0.0, 'number': 0.0, 'conj': 0.44117647058823534, 'inhib': 0.0, 'bio': 0.20588235294117646, 'relig': 0.0, 'auxverb': 0.3235294117647059, 'incl': 0.14705882352941174, 'verb': 0.5882352941176471, 'certain': 0.11764705882352941, 'anger': 0.0, 'affect': 0.2647058823529412, 'work': 0.0, 'achieve': 0.029411764705882353}
#
# word: take
# cat numbers: ['11', '14']
# word: quite
# cat numbers: ['131', '135']
# word: at
# cat numbers: ['1', '17', '252', '250']
# word: or
# cat numbers: ['1', '18', '131', '135', '139']
# word: if
# cat numbers: ['1', '18', '131', '134', '135', '139']
# word: i
# cat numbers: ['1', '2', '3', '4']
# word: nap
# cat numbers: ['356']
# word: id
# cat numbers: ['1', '2', '3', '4', '11', '12']
# word: ears
# cat numbers: ['140', '142', '146', '147']
# word: life
# cat numbers: ['146', '148']
# word: not
# cat numbers: ['1', '19', '131', '139']
# word: am
# cat numbers: ['11', '1', '12', '14']
# word: it
# cat numbers: ['1', '2', '9']
# word: face
# cat numbers: ['146', '147']
# word: er
# cat numbers: ['463']
# word: ma
# cat numbers: ['121', '122']
# word: is
# cat numbers: ['11', '1', '12', '14']
# word: quit
# cat numbers: ['355']
# word: main
# cat numbers: ['1', '20']
# word: so
# cat numbers: ['1', '16', '18']
# word: ha
# cat numbers: ['125', '126', '462']
# word: pa
# cat numbers: ['121', '122']
# word: part
# cat numbers: ['1', '20']
# word: my
# cat numbers: ['1', '2', '3', '4']
# word: did
# cat numbers: ['11', '1', '12', '13']
# word: a
# cat numbers: ['1', '10']
# word: ye
# cat numbers: ['1', '2', '3', '6', '121']
# word: ace
# cat numbers: ['355']
# word: year
# cat numbers: ['253', '250']
# word: in
# cat numbers: ['1', '17', '252', '250']
# word: ok
# cat numbers: ['125', '126', '462']
# word: of
# cat numbers: ['1', '17']
# word: pc*
# cat numbers: ['354']
# word: dail*
# cat numbers: ['253', '250']
# word: no
# cat numbers: ['1', '19']
# word: to
# cat numbers: ['1', '17']
# word: art
# cat numbers: ['356']
# word: ear
# cat numbers: ['140', '142', '146', '147']
# word: years
# cat numbers: ['253', '250']
# word: yea
# cat numbers: ['462']
# Text:
# Ten years to? A Twitter remain. For facebook, Twitter, Instagram is a part of my daily life. Snapchat did not take it place. Linkedin not quite so.
# Liwc:
# {'excl': 0.11764705882352941, 'space': 0.11764705882352941, 'health': 0.029411764705882353, 'negate': 0.11764705882352941, 'social': 0.08823529411764705, 'friend': 0.0, 'humans': 0.0, 'family': 0.058823529411764705, 'nonfl': 0.058823529411764705, 'quant': 0.058823529411764705, 'pronoun': 0.5294117647058824, 'you': 0.029411764705882353, 'percept': 0.058823529411764705, 'shehe': 0.0, 'posemo': 0.058823529411764705, 'funct': 1.4117647058823526, 'present': 0.08823529411764705, 'filler': 0.0, 'death': 0.0, 'see': 0.0, 'past': 0.029411764705882353, 'ingest': 0.0, 'ppron': 0.411764705882353, 'relativ': 0.2058823529411765, 'ipron': 0.11764705882352941, 'feel': 0.0, 'insight': 0.0, 'cogmech': 0.14705882352941174, 'tentat': 0.08823529411764705, 'body': 0.08823529411764705, 'i': 0.3823529411764706, 'time': 0.08823529411764705, 'swear': 0.0, 'motion': 0.0, 'future': 0.0, 'home': 0.0, 'leisure': 0.058823529411764705, 'anx': 0.0, 'money': 0.0, 'article': 0.35294117647058826, 'discrep': 0.029411764705882353, 'they': 0.0, 'cause': 0.0, 'sexual': 0.0, 'hear': 0.058823529411764705, 'negemo': 0.0, 'we': 0.0, 'assent': 0.08823529411764705, 'preps': 0.17647058823529413, 'WC': 34, 'adverb': 0.029411764705882353, 'sad': 0.0, 'number': 0.0, 'conj': 0.08823529411764705, 'inhib': 0.0, 'bio': 0.11764705882352941, 'relig': 0.0, 'auxverb': 0.11764705882352941, 'incl': 0.0, 'verb': 0.14705882352941177, 'certain': 0.0, 'anger': 0.0, 'affect': 0.058823529411764705, 'work': 0.029411764705882353, 'achieve': 0.08823529411764705}

# %%
words["(02 134)125/464"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-320-eaccff0b7397> in <module>()
# ----> 1 words["(02 134)125/464"]
#
# KeyError: '(02 134)125/464'

# %%
cats

# %% [markdown]
# # Transformation of raw LIWC .dic file to pickled cats and words dictionaries

# %%
# !ls

# %%
dicf = open("LIWC2007_English131104.dic")
dics = dicf.read()

# %%
cats_test = """%
1	funct
2	pronoun
3	ppron
%
also	1	2	3
altar*	1
although	1	3
"""

# Parse the categories and their corresponding number
cats_patt = re.compile(r"%([\w\d\t\n]+)%")
cats_res = cats_patt.search(dics)
cats_string = cats_res.group(1)
print(cats_string)
cat_patt = re.compile(r"(?P<catnum>\d+)\t(?P<catname>\w+\*?)")
cats = {}
for item in cats_string.split("\n"):
    if item != "":
        cat_res = cat_patt.search(item)
        cats[cat_res.group("catnum")] = cat_res.group("catname")
pickle.dump(cats, open("liwc_2007_cats_dict.pickle","wb"))
print(cats)

# Parse words
word_line_patt = re.compile(r"[^\W\d_]") # a "negative" way of getting alpha characters only
words = {}
for row in dics.split("\n"):
    if word_line_patt.match(row):
        items = row.split("\t")
        words[items[0]] = items[1:]
pickle.dump(words, open("liwc_2007_words_dict.pickle","wb"))
words_only = list(words.keys())
random.shuffle(words_only)
print(words_only[:20])
# Out:
# 1	funct
# 2	pronoun
# 3	ppron
# 4	i
# 5	we
# 6	you
# 7	shehe
# 8	they
# 9	ipron
# 10	article
# 11	verb
# 12	auxverb
# 13	past
# 14	present
# 15	future
# 16	adverb
# 17	preps
# 18	conj
# 19	negate
# 20	quant
# 21	number
# 22	swear
# 121	social
# 122	family
# 123	friend
# 124	humans
# 125	affect
# 126	posemo
# 127	negemo
# 128	anx
# 129	anger
# 130	sad
# 131	cogmech
# 132	insight
# 133	cause
# 134	discrep
# 135	tentat
# 136	certain
# 137	inhib
# 138	incl
# 139	excl
# 140	percept
# 141	see
# 142	hear
# 143	feel
# 146	bio
# 147	body
# 148	health
# 149	sexual
# 150	ingest
# 250	relativ
# 251	motion
# 252	space
# 253	time
# 354	work
# 355	achieve
# 356	leisure
# 357	home
# 358	money
# 359	relig
# 360	death
# 462	assent
# 463	nonfl
# 464	filler
#
# {'142': 'hear', '4': 'i', '125': 'affect', '11': 'verb', '356': 'leisure', '148': 'health', '124': 'humans', '355': 'achieve', '22': 'swear', '126': 'posemo', '147': 'body', '357': 'home', '463': 'nonfl', '134': 'discrep', '136': 'certain', '16': 'adverb', '253': 'time', '7': 'shehe', '6': 'you', '128': 'anx', '150': 'ingest', '9': 'ipron', '132': 'insight', '360': 'death', '139': 'excl', '252': 'space', '18': 'conj', '14': 'present', '133': 'cause', '359': 'relig', '13': 'past', '1': 'funct', '15': 'future', '354': 'work', '462': 'assent', '121': 'social', '251': 'motion', '17': 'preps', '135': 'tentat', '250': 'relativ', '2': 'pronoun', '137': 'inhib', '130': 'sad', '122': 'family', '149': 'sexual', '19': 'negate', '123': 'friend', '138': 'incl', '141': 'see', '5': 'we', '146': 'bio', '131': 'cogmech', '20': 'quant', '21': 'number', '140': 'percept', '464': 'filler', '10': 'article', '358': 'money', '143': 'feel', '8': 'they', '3': 'ppron', '127': 'negemo', '129': 'anger', '12': 'auxverb'}
# ['potential*', 'practice', 'desk*', 'stress*', 'borderline*', 'coworker*', 'mate', 'evaluat*', "isn't", 'good', 'front', 'yoga', 'advertising', 'tensing', 'fallen', 'dropout*', 'speak', 'sweetness*', 'book*', 'pink*']

# %%
l = [random.randint(0,9) for i in range(153)]

# %%
len(l) % 10

# %%
[tkn for tkn in re.split(r"[ \.,\!\?\n\(\)]", a_text) if not tkn == ""]
# Out:
# ["She's",
#  'mine',
#  'I',
#  'adore',
#  'her',
#  'No',
#  'matter',
#  'what',
#  'I',
#  'will',
#  'always',
#  'love',
#  'her',
#  '-',
#  'my',
#  'special',
#  'honey',
#  'Idag',
#  'har',
#  'jag',
#  'varit',
#  'tio',
#  'år',
#  'på',
#  'Twitter',
#  '232987',
#  'tweets',
#  '14715',
#  'följare',
#  'Vunnit',
#  'Sveriges',
#  'meste',
#  'Twittrare',
#  '2009',
#  'Idag',
#  'är',
#  'min',
#  'average',
#  '87',
#  'tweets',
#  'per',
#  'dag',
#  'Den',
#  'var',
#  'mycket',
#  'högre',
#  'förut',
#  'Twitter',
#  'har',
#  'gett',
#  'mig',
#  'en',
#  'massa',
#  'bra',
#  'En',
#  'massa',
#  'jobb',
#  'mängder',
#  'av',
#  'vänner',
#  'och',
#  'en',
#  'del',
#  'fiender',
#  'stor',
#  'kunskap',
#  'Det',
#  'bästa',
#  'är',
#  'att',
#  'Twitter',
#  'gav',
#  'mig',
#  'min',
#  'bästa',
#  'vän',
#  'och',
#  'min',
#  'kompanjon',
#  'Sarah',
#  'aka',
#  '@sanasilb',
#  'Hon',
#  'betyder',
#  'oerhört',
#  'mycket',
#  'Tacksam',
#  'för',
#  'att',
#  'hon',
#  'började',
#  'stalka',
#  'mig',
#  'våren',
#  '2010',
#  'Livet',
#  'hade',
#  'helt',
#  'klart',
#  'sett',
#  'annorlunda',
#  'ut',
#  'utan',
#  'Twitter',
#  'även',
#  'om',
#  'de',
#  'senaste',
#  'åren',
#  'har',
#  'inneburit',
#  'mindre',
#  'twittrande',
#  'eftersom',
#  'jag',
#  'helt',
#  'enkelt',
#  'inte',
#  'riktigt',
#  'längre',
#  'känner',
#  'mig',
#  'hemma',
#  'där',
#  'Det',
#  'är',
#  'annorlunda',
#  'Det',
#  'är',
#  'mer',
#  'broadcast',
#  'Och',
#  'även',
#  'om',
#  'jag',
#  'gillar',
#  'algoritmerna',
#  'på',
#  'Instagram',
#  'och',
#  'Facebook',
#  'så',
#  'ogillar',
#  'jag',
#  'hur',
#  'den',
#  'implementerats',
#  'på',
#  'Twitter',
#  'Samtidigt',
#  'som',
#  'jag',
#  'ogillar',
#  'Tweetbot',
#  'så',
#  'jag',
#  'kommer',
#  'liksom',
#  'inte',
#  'undan',
#  'den',
#  'Tio',
#  'år',
#  'till',
#  'Om',
#  'Twitter',
#  'finns',
#  'kvar',
#  'För',
#  'Facebook',
#  'Twitter',
#  'Instagram',
#  'är',
#  'en',
#  'del',
#  'av',
#  'min',
#  'vardag',
#  'Snapchat',
#  'lyckades',
#  'inte',
#  'ta',
#  'den',
#  'platsen',
#  'Linkedin',
#  'inte',
#  'fullt',
#  'så']
