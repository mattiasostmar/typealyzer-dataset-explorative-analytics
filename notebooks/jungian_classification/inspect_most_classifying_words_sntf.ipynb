# %%
import pandas as pd
import requests
from collections import defaultdict
import os
import operator
import pickle
import time
from collections import Counter
from datetime import datetime

# %%
df_pickle_path = "../../pickles/dataframe_survey_2018-01-23_enriched.pickle"

# %%
indata = pd.read_pickle(df_pickle_path)
print(indata[["actual","actual_temp","is_s"]].head(5))
print(indata[["actual","actual_temp","is_s"]].tail(5))
# Out:
#    actual actual_temp  is_s
# 1    INFJ          nf     0
# 2    INFP          nf     0
# 3    INTP          nt     0
# 5    ENFJ          nf     0
# 10   INFP          nf     0
#       actual actual_temp  is_s
# 25432   INTJ          nt     0
# 25433   INTP          nt     0
# 25435   INFP          nf     0
# 25436   ENFP          nf     0
# 25437   INFP          nf     0

# %% [markdown]
# # Remove non-English texts

# %%
len(indata)
# Out:
# 22919

# %%
indata = indata[indata.lang == "en"]

# %%
len(indata)
# Out:
# 22588

# %% [markdown]
# # Sample n texts per class

# %%
sntf_samples = pd.concat([
            indata[indata.func == "s"].sample(100, random_state=123456)[["text","tokens","func","actual_temp"]],
            indata[indata.func == "n"].sample(100, random_state=123456)[["text","tokens","func","actual_temp"]],
            indata[indata.func == "t"].sample(100, random_state=123456)[["text","tokens","func","actual_temp"]],
            indata[indata.func == "f"].sample(100, random_state=123456)[["text","tokens","func","actual_temp"]]
            ])

# %%
sntf_samples
# Out:
#                                                     text  tokens func  \
# 9630   Sweetdreamsmusic ☁ theme ▶ o t 7 h e a v e n S...     634    s
# 384    Book.Blog.Bake. | Taking on one book & one rec...    4704    s
# 13750  --> Time and Tide and Buttered Eggs Wait for n...    1019    s
# 5455   one swood guy please pick only one column plea...      67    s
# 5226   pop pop about archive message Theme by Theme S...      73    s
# 20565  cunning cunning Mainly hp, with a mix of other...     415    s
# 2563   Paradox >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>...     237    s
# 2162   Peek into what's in my brain. Peek into what's...     158    s
# 20023  Innocent Dreams Return Message Archive Theme F...     414    s
# 14383  Geronimo! I II III IV V VI Geronimo! Hi. I'm S...     493    s
# 24989  For The Love Of Math! | I love math more than ...    5596    s
# 9479   Sans titre Sans titre Ask me anything 36668 --...      22    s
# 12377  auspicious--INFP auspicious--INFP Home     Inf...      32    s
# 21433  menu college music tags and links my affinity ...     250    s
# 9533   love will never be forever home ask about tagl...      73    s
# 22385  living oxymoron thought of the week: to reveal...     316    s
# 8649   auspicious--INFP auspicious--INFP Home     Inf...      32    s
# 8565   Collection Of Paradoxes Theme by Theme Static ...     214    s
# 14613  je ne regrette rien je ne regrette rien REW/21...     921    s
# 10217              pretty isn't everything you punkass         5    s
# 22716  the light is white | Just one little Catholic ...    1589    s
# 15836  kissed by fire home message Submit archive the...     550    s
# 16166  Distortions Distortions blvckshogun : theairto...     388    s
# 2742   Land of Imagination and Myth Land of Imaginati...     357    s
# 2380   John Green's tumblr >>>>>>>>>>>>>>>>>>>>>>>>>>...     921    s
# 6349   Cuteness ℤ zeldathemes home message submit Moi...    1443    s
# 22435  Here's a flighty one. Here's a flighty one. Co...     363    s
# 2863   Will Blog for Food Will Blog for Food 18 | Bis...     982    s
# 4282   before my heart is lost { i'll tie you in my a...     420    s
# 17978  ♥ My Mom Still Loves Me ♥ ♥ My Mom Still Loves...     307    s
# ...                                                  ...     ...  ...
# 16536                       Hair the Color of Lemons           5    f
# 18700  Sorry, you were saying? You are using an outda...     554    f
# 7233   Ask the Dragon Ball Fandom Hey! I had a questi...     509    f
# 9588   Röyhkeä suttura Brazen hussy from Finland. Doc...     317    f
# 17189  with you 'til the end of the line with you 'ti...     335    f
# 14300  No Day But Today No Day But Today Hi! Welcome ...     811    f
# 20018  IndeDrum Index Ask Archive Night Theme IndeDru...     272    f
# 10018  just a kid who wears 2 much red lipstick ◢ ◢ ◢...     560    f
# 11384  HOT PANTS HOMO Home about+tags SAY TO ME A THI...     571    f
# 21520  music questions jr | socal This is a more-or-l...     264    f
# 16650  Fear and Loathing in Los Santos Fear and Loath...     115    f
# 703    WELCUM 2 FAYSBEWK WELCUM 2 FAYSBEWK Time-wasti...     824    f
# 22522  Nessa's Blog Questions?     RSS     Archive   ...     636    f
# 5505   Defend Pop Punk Defend Pop Punk Heyo, my name ...    1006    f
# 11494  외로운 소년 외로운 소년 » kevin || 17 || ♂ key-net navig...     103    f
# 14186  10 points to dumbledore 10 points to dumbledor...     409    f
# 13907  Falling Down the Rabbit Hole... >>>>>>>>>>>>>>...     536    f
# 9826   Hi. I'm Becca. z zeldathemes Hi. I'm Becca. ho...    1208    f
# 21900  A twitch upon the thread. A twitch upon the th...     218    f
# 13430  ☄ Next Ask Ali Submit Visuals Personal My Writ...     256    f
# 9184   Please don't notice me, Senpai ”> _ ▢ x wander...     352    f
# 19859  the person who needs a life RSS Archive Likes ...     791    f
# 19622                                He's In Love With         4    f
# 5366   spamano>>everything else megan // ♀ // 16 some...      68    f
# 1437   The Gates of Delirium The Gates of Delirium Ho...      38    f
# 3873   you're more than that. THEME you're more than ...    2058    f
# 5569   south korea is back at it again hi im manda an...     534    f
# 8272   the bite is a gift the bite is a gift narnia m...     551    f
# 9788   Put yah guns on!! deviantart cosplay my life a...     240    f
# 25333  Artist in a Half Shell - Page 1 of 27 Artist i...     502    f
#
#       actual_temp
# 9630           nf
# 384            nf
# 13750          nt
# 5455           nf
# 5226           nf
# 20565          sf
# 2563           nf
# 2162           nf
# 20023          sf
# 14383          nt
# 24989          nt
# 9479           nf
# 12377          nf
# 21433          nf
# 9533           nf
# 22385          nt
# 8649           nf
# 8565           st
# 14613          nt
# 10217          nf
# 22716          nf
# 15836          nf
# 16166          nt
# 2742           nf
# 2380           nf
# 6349           sf
# 22435          nf
# 2863           nf
# 4282           st
# 17978          nt
# ...           ...
# 16536          nt
# 18700         NaN
# 7233           nt
# 9588           nf
# 17189          nt
# 14300          st
# 20018          nt
# 10018          nf
# 11384          nf
# 21520          nt
# 16650          nf
# 703            st
# 22522          nt
# 5505           nt
# 11494          nf
# 14186          sf
# 13907          sf
# 9826          NaN
# 21900          nt
# 13430          nf
# 9184           nf
# 19859          nt
# 19622         NaN
# 5366           sf
# 1437           nt
# 3873           nt
# 5569           sf
# 8272           nt
# 9788           sf
# 25333          nt
#
# [400 rows x 4 columns]

# %% [markdown]
# # Rough tokenization of the sampled texts

# %%
tokens = set()
for ix, text in sntf_samples.iterrows():
    for token in text["text"].split():
        tokens.add(token)
len(tokens)
# Out:
# 40488

# %%
# to Jon
tokens_s = pd.Series(list(tokens))
tokens_s.to_string("../../data/processed/tokens_n40488_100samples_per_class_sntf.txt")

# %% [raw]
# 15 samples = e.g. 10839 tokens
# 30 samples = e.g. 17291 tokens
# 50 samples = e.g. 24842 tokens
# 100 samples = e.g. 40488 tokens

# %% [markdown]
# # Classify word-for-word, classifier-for_classifier

# %%
def classify_jung_percieving_function_of_text(text):
    """Does what it says, pretty much."""
    header = {"Content-Type": "application/json",
             "Authorization": "Token " + os.environ["UCLASSIFY_READ"]}
    data = {"texts":[text]} # send a one-item list for now, since we don't have a feel for sizes
    try:
        result = requests.post("https://api.uclassify.com/v1/prfekt/jungian-cognitive-function-sensing-intuition/classify",
                       json = data,
                       headers = header)
    except Exception as e:
        time.sleep(600)
        print("Error connecting with uClassify. Sleeping 10 minutes and retrying.")
        result = requests.post("https://api.uclassify.com/v1/prfekt/jungian-cognitive-function-sensing-intuition/classify",
                       json = data,
                       headers = header)
        
    json_result = result.json()
    
    res_dict = {"s":0, "n":0}
    
    for classItem in json_result[0]["classification"]:
        res_dict[classItem["className"]] = classItem["p"]
    
    # sorted_dict = sorted(res_dict.items(), key=operator.itemgetter(1), reverse=True)
    return res_dict

def classify_jung_judging_function_of_text(text):
    """Does what it says, pretty much."""
    header = {"Content-Type": "application/json",
             "Authorization": "Token " + os.environ["UCLASSIFY_READ"]}
    data = {"texts":[text]} # send a one-item list for now, since we don't have a feel for sizes
    try:
        result = requests.post("https://api.uclassify.com/v1/prfekt/jungian-cognitive-function-thinking-feeling/classify",
                       json = data,
                       headers = header)
    except Exception as e:
        time.sleep(600)
        print("Error connecting with uClassify. Sleeping 10 minutes and retrying.")
        result = requests.post("https://api.uclassify.com/v1/prfekt/jungian-cognitive-function-thinking-feeling/classify",
                       json = data,
                       headers = header)
    
    json_result = result.json()
    
    res_dict = {"t":0, "f":0}
    
    for classItem in json_result[0]["classification"]:
        res_dict[classItem["className"]] = classItem["p"]
    
    # sorted_dict = sorted(res_dict.items(), key=operator.itemgetter(1), reverse=True)
    return res_dict

# %%
startTime = datetime.now()
results = defaultdict(list)
# Result order S,N,T,F
word_cnt = 1
for word in tokens:
    for name in ["sn","tf"]:
        if name == "sn":
            # classify and store results in order s, n in results dict e.g. results["smokin"].appen(sResultValue)
            res = classify_jung_percieving_function_of_text(word)
            results[word].append(res["s"])
            results[word].append(res["n"])
        else:
            res = classify_jung_judging_function_of_text(word)
            results[word].append(res["t"])
            results[word].append(res["f"])
    word_cnt +=1
    if word_cnt % 100 == 0:
            print("word {} of {} classified".format(word_cnt, len(tokens)))
            print("Time taken: {}".format(datetime.now() - startTime))
# Out:
# word 100 of 40488 classified
# Time taken: 0:01:33.941238

# %% [markdown]
# # Get keywords from classifiers via keywords endpoint

# %%
def get_keywords_from_uclassify_perceiving_classifer(text):
    """
    Uses the keywords endpoint inherent in each classifier on uClassify
    to retrieve the most significant keywords for each class.
    
    See: https://www.uclassify.com/docs/restapi#readcalls-keywords
    ."""
    header = {"Content-Type": "application/json",
             "Authorization": "Token " + os.environ["UCLASSIFY_READ"]}
    data = {"texts":[text]} # send a one-item list for now, since we don't have a feel for sizes
    try:
        result = requests.post("https://api.uclassify.com/v1/prfekt/jungian-cognitive-function-sensing-intuition/keywords",
                       json = data,
                       headers = header)
    except Exception as e:
        time.sleep(180)
        print("Error connecting with uClassify. Sleeping 3 minutes and retrying.")
        result = requests.post("https://api.uclassify.com/v1/prfekt/jungian-cognitive-function-sensing-intuition/keywords",
                       json = data,
                       headers = header)
    
    return result.json()

def get_keywords_from_uclassify_judging_classifer(text):
    """
    Uses the keywords endpoint inherent in each classifier on uClassify
    to retrieve the most significant keywords for each class.
    
    See: https://www.uclassify.com/docs/restapi#readcalls-keywords
    ."""
    header = {"Content-Type": "application/json",
             "Authorization": "Token " + os.environ["UCLASSIFY_READ"]}
    data = {"texts":[text]} # send a one-item list for now, since we don't have a feel for sizes
    try:
        result = requests.post("https://api.uclassify.com/v1/prfekt/jungian-cognitive-function-thinking-feeling/keywords",
                       json = data,
                       headers = header)
    except Exception as e:
        time.sleep(180)
        print("Error connecting with uClassify. Sleeping 3 minutes and retrying.")
        result = requests.post("https://api.uclassify.com/v1/prfekt/jungian-cognitive-function-thinking-feeling/keywords",
                       json = data,
                       headers = header)
    
    return result.json()

# %% [markdown]
# # Perceiving

# %%
tokens_str = " ".join(tokens)
tokens_str[:30]
# Out:
# 'region peeta Jade Delphine THE'

# %%
len(tokens_str)
# Out:
# 343716

# %%
startTime = datetime.now()
res = get_keywords_from_uclassify_perceiving_classifer(tokens_str)
print("took {}".format(datetime.now() - startTime))
# Out:
# took 0:00:01.260022

# %%
res
# Out:
# [[{'className': 's', 'keyword': '#x', 'p': 0.996307},
#   {'className': 'n', 'keyword': 'ziad', 'p': 0.996454},
#   {'className': 'n', 'keyword': 'earthstory', 'p': 0.996454},
#   {'className': 'n', 'keyword': 'settlement', 'p': 0.996894},
#   {'className': 'n', 'keyword': 'increased', 'p': 0.996454},
#   {'className': 'n', 'keyword': 'saleh', 'p': 0.996454},
#   {'className': 's', 'keyword': 'lancaster', 'p': 0.996589},
#   {'className': 's', 'keyword': 'ashlyn', 'p': 0.997883},
#   {'className': 'n', 'keyword': 'deir', 'p': 0.998084},
#   {'className': 'n', 'keyword': 'doctrines', 'p': 0.996689},
#   {'className': 'n', 'keyword': '↱', 'p': 0.996689},
#   {'className': 's', 'keyword': 'jace', 'p': 0.996589},
#   {'className': 's', 'keyword': 'noot', 'p': 0.997661},
#   {'className': 'n', 'keyword': 'toggle', 'p': 0.996894},
#   {'className': 's', 'keyword': '#ph', 'p': 0.997041},
#   {'className': 'n', 'keyword': 'modesty', 'p': 0.997925},
#   {'className': 'n', 'keyword': 'funnymomentposts', 'p': 0.998915},
#   {'className': 'n', 'keyword': 'thelightiswhite', 'p': 0.998812},
#   {'className': 'n', 'keyword': 'thepatheticaesthetic', 'p': 0.998392},
#   {'className': 'n', 'keyword': 'khaled', 'p': 0.997076},
#   {'className': 'n', 'keyword': 'youfoundmj', 'p': 0.998652},
#   {'className': 'n', 'keyword': 'pooped', 'p': 0.996894},
#   {'className': 'n', 'keyword': 'ooooooooo', 'p': 0.999307},
#   {'className': 's', 'keyword': 'lin', 'p': 0.997979},
#   {'className': 'n', 'keyword': 'centreforaviation', 'p': 0.997076},
#   {'className': 'n', 'keyword': 'roche', 'p': 0.999469},
#   {'className': 's', 'keyword': '¶', 'p': 0.997883},
#   {'className': 'n', 'keyword': 'bankruptspermbank', 'p': 0.998282},
#   {'className': 'n', 'keyword': '☩', 'p': 0.997738},
#   {'className': 'n', 'keyword': 'rosary', 'p': 0.99763}]]

# %%
kw = pd.DataFrame(res[0])
kw.className.value_counts()
# Out:
# n    22
# s     8
# Name: className, dtype: int64

# %%
sDf = kw[kw.className == "s"]
nDf = kw[kw.className == "n"]

# %%
sDf.loc[sDf.p.sort_values(ascending=False).index]
# Out:
#    className    keyword         p
# 23         s        lin  0.997979
# 26         s          ¶  0.997883
# 7          s     ashlyn  0.997883
# 12         s       noot  0.997661
# 14         s        #ph  0.997041
# 11         s       jace  0.996589
# 6          s  lancaster  0.996589
# 0          s         #x  0.996307

# %%
nDf.loc[nDf.p.sort_values(ascending=False).index]
# Out:
#    className               keyword         p
# 25         n                 roche  0.999469
# 22         n             ooooooooo  0.999307
# 16         n      funnymomentposts  0.998915
# 17         n       thelightiswhite  0.998812
# 20         n            youfoundmj  0.998652
# 18         n  thepatheticaesthetic  0.998392
# 27         n     bankruptspermbank  0.998282
# 8          n                  deir  0.998084
# 15         n               modesty  0.997925
# 28         n                     ☩  0.997738
# 29         n                rosary  0.997630
# 19         n                khaled  0.997076
# 24         n     centreforaviation  0.997076
# 21         n                pooped  0.996894
# 13         n                toggle  0.996894
# 3          n            settlement  0.996894
# 10         n                     ↱  0.996689
# 9          n             doctrines  0.996689
# 5          n                 saleh  0.996454
# 4          n             increased  0.996454
# 2          n            earthstory  0.996454
# 1          n                  ziad  0.996454

# %% [markdown]
# # Perceiving: get keywords from most common words

# %%
common_tokens = Counter()
for ix, text in sntf_samples.iterrows():
    common_tokens.update(text["text"].split())
common_tokens.most_common(10)
# Out:
# [('the', 4878),
#  ('and', 3669),
#  ('to', 3569),
#  ('I', 3182),
#  ('a', 3106),
#  (':', 2940),
#  ('of', 2899),
#  ('in', 2042),
#  ('notes', 2015),
#  ('is', 1750)]

# %%
common_tokens_list = []
for tup in common_tokens.most_common(1500):
    common_tokens_list.append(tup[0])

# %%
len(common_tokens_list)
# Out:
# 1500

# %%
# remove n most common tokens
common_tokens_list = common_tokens_list[500:]

# %%
common_tokens_str = " ".join(common_tokens_list)
common_tokens_str[:30]
# Out:
# 'words months point another alm'

# %%
common_perc_res = get_keywords_from_uclassify_perceiving_classifer(common_tokens_str)
common_perc_res
# Out:
# [[{'className': 's', 'keyword': '2nd', 'p': 0.67344},
#   {'className': 'n', 'keyword': 'pinterest', 'p': 0.676971},
#   {'className': 's', 'keyword': 'spock', 'p': 0.673587},
#   {'className': 's', 'keyword': '7th', 'p': 0.711965},
#   {'className': 'n', 'keyword': 'poetry', 'p': 0.687495},
#   {'className': 'n', 'keyword': 'palestinian', 'p': 0.71323},
#   {'className': 's', 'keyword': '↳', 'p': 0.687896},
#   {'className': 's', 'keyword': 'lvl', 'p': 0.760022},
#   {'className': 'n', 'keyword': '‘', 'p': 0.733083},
#   {'className': 'n', 'keyword': 'israel', 'p': 0.728096},
#   {'className': 's', 'keyword': '･', 'p': 0.83395},
#   {'className': 'n', 'keyword': '■', 'p': 0.764686},
#   {'className': 's', 'keyword': 'ho', 'p': 0.730921},
#   {'className': 'n', 'keyword': 'israeli', 'p': 0.724133},
#   {'className': 's', 'keyword': '☂', 'p': 0.691112},
#   {'className': 's', 'keyword': '—i', 'p': 0.959016},
#   {'className': 'n', 'keyword': 'gaza', 'p': 0.940188},
#   {'className': 'n', 'keyword': '☩', 'p': 0.997738},
#   {'className': 's', 'keyword': '±', 'p': 0.764574},
#   {'className': 's', 'keyword': 'aoû', 'p': 0.748644},
#   {'className': 'n', 'keyword': 'wage', 'p': 0.735467},
#   {'className': 'n', 'keyword': '↲', 'p': 0.927867},
#   {'className': 'n', 'keyword': 'kuroh', 'p': 0.954545},
#   {'className': 's', 'keyword': 'spotted', 'p': 0.770494},
#   {'className': 'n', 'keyword': 'pooped', 'p': 0.996894},
#   {'className': 'n', 'keyword': '↱', 'p': 0.996689},
#   {'className': 'n', 'keyword': 'palestine', 'p': 0.795506},
#   {'className': 'n', 'keyword': 'myersandbriggs', 'p': 0.786123},
#   {'className': 'n', 'keyword': '☁', 'p': 0.879057},
#   {'className': 's', 'keyword': 'thou', 'p': 0.919984}]]

# %%
common_perc_kw = pd.DataFrame(common_res[0])
common_perc_kw.className.value_counts()
# Out:
# n    17
# s    13
# Name: className, dtype: int64

# %%
common_sDf = common_perc_kw[common_perc_kw.className == "s"]
common_nDf = common_perc_kw[common_perc_kw.className == "n"]

# %%
common_sDf
# Out:
#    className  keyword         p
# 0          s      2nd  0.673440
# 2          s    spock  0.673587
# 3          s      7th  0.711965
# 6          s        ↳  0.687896
# 7          s      lvl  0.760022
# 10         s        ･  0.833950
# 12         s       ho  0.730921
# 14         s        ☂  0.691112
# 15         s       —i  0.959016
# 18         s        ±  0.764574
# 19         s      aoû  0.748644
# 23         s  spotted  0.770494
# 29         s     thou  0.919984

# %%
common_nDf
# Out:
#    className         keyword         p
# 1          n       pinterest  0.676971
# 4          n          poetry  0.687495
# 5          n     palestinian  0.713230
# 8          n               ‘  0.733083
# 9          n          israel  0.728096
# 11         n               ■  0.764686
# 13         n         israeli  0.724133
# 16         n            gaza  0.940188
# 17         n               ☩  0.997738
# 20         n            wage  0.735467
# 21         n               ↲  0.927867
# 22         n           kuroh  0.954545
# 24         n          pooped  0.996894
# 25         n               ↱  0.996689
# 26         n       palestine  0.795506
# 27         n  myersandbriggs  0.786123
# 28         n               ☁  0.879057

# %% [markdown]
# # Judging

# %%
tokens_str = " ".join(tokens)
tokens_str[:30]
# Out:
# 'region peeta Jade Delphine THE'

# %%
res = get_keywords_from_uclassify_judging_classifer(tokens_str)
res
# Out:
# [[{'className': 'f', 'keyword': 'veganism', 'p': 0.997285},
#   {'className': 'f', 'keyword': 'agonistes', 'p': 0.997569},
#   {'className': 'f', 'keyword': 'brideshead', 'p': 0.997285},
#   {'className': 'f', 'keyword': 'blimeycow', 'p': 0.997899},
#   {'className': 't', 'keyword': 'kepler', 'p': 0.99763},
#   {'className': 't', 'keyword': 'cosmicvastness', 'p': 0.99763},
#   {'className': 't', 'keyword': 'sodium', 'p': 0.997382},
#   {'className': 't', 'keyword': 'renamonkalou', 'p': 0.998008},
#   {'className': 't', 'keyword': 'astronomyandastrophotography', 'p': 0.998652},
#   {'className': 't', 'keyword': 'cassini', 'p': 0.997835},
#   {'className': 't', 'keyword': 'thepatheticaesthetic', 'p': 0.999405},
#   {'className': 'f', 'keyword': '©mc', 'p': 0.99769},
#   {'className': 't', 'keyword': 'Август', 'p': 0.998339},
#   {'className': 'f', 'keyword': 'amalia', 'p': 0.997569},
#   {'className': 'f', 'keyword': 'jaegerhugs', 'p': 0.997569},
#   {'className': 't', 'keyword': 'bankruptspermbank', 'p': 0.99896},
#   {'className': 't', 'keyword': 'ooooooo', 'p': 0.999701},
#   {'className': 't', 'keyword': 'leenthemes', 'p': 0.998783},
#   {'className': 't', 'keyword': 'ooooooooooo', 'p': 0.998783},
#   {'className': 't', 'keyword': 'centreforaviation', 'p': 0.99904},
#   {'className': 'f', 'keyword': 'lulazel', 'p': 0.999187},
#   {'className': 't', 'keyword': 'roche', 'p': 0.999828},
#   {'className': 'f', 'keyword': 'thelightiswhite', 'p': 0.999428},
#   {'className': 't', 'keyword': 'youfoundmj', 'p': 0.998866},
#   {'className': 't', 'keyword': 'dmeri055', 'p': 0.998615},
#   {'className': 't', 'keyword': 'funnymomentposts', 'p': 0.999554},
#   {'className': 't', 'keyword': 'kenny-west17', 'p': 0.998615},
#   {'className': 't', 'keyword': 'earthstory', 'p': 0.99884},
#   {'className': 't', 'keyword': 'oooooooooo', 'p': 0.998812},
#   {'className': 't', 'keyword': 'barazani', 'p': 0.998783}]]

# %%
kw = pd.DataFrame(res[0])
tDf = kw[kw.className == "t"]
fDf = kw[kw.className == "f"]
kw.className.value_counts()
# Out:
# t    21
# f     9
# Name: className, dtype: int64

# %%
tDf.loc[tDf.p.sort_values(ascending=False).index]
# Out:
#    className                       keyword         p
# 21         t                         roche  0.999828
# 16         t                       ooooooo  0.999701
# 25         t              funnymomentposts  0.999554
# 10         t          thepatheticaesthetic  0.999405
# 19         t             centreforaviation  0.999040
# 15         t             bankruptspermbank  0.998960
# 23         t                    youfoundmj  0.998866
# 27         t                    earthstory  0.998840
# 28         t                    oooooooooo  0.998812
# 29         t                      barazani  0.998783
# 17         t                    leenthemes  0.998783
# 18         t                   ooooooooooo  0.998783
# 8          t  astronomyandastrophotography  0.998652
# 24         t                      dmeri055  0.998615
# 26         t                  kenny-west17  0.998615
# 12         t                        Август  0.998339
# 7          t                  renamonkalou  0.998008
# 9          t                       cassini  0.997835
# 5          t                cosmicvastness  0.997630
# 4          t                        kepler  0.997630
# 6          t                        sodium  0.997382

# %%
fDf.loc[fDf.p.sort_values(ascending=False).index]
# Out:
#    className          keyword         p
# 22         f  thelightiswhite  0.999428
# 20         f          lulazel  0.999187
# 3          f        blimeycow  0.997899
# 11         f              ©mc  0.997690
# 14         f       jaegerhugs  0.997569
# 13         f           amalia  0.997569
# 1          f        agonistes  0.997569
# 2          f       brideshead  0.997285
# 0          f         veganism  0.997285

# %% [markdown]
# # Judging: get keywords from most common words

# %%
common_tokens = Counter()
for ix, text in sntf_samples.iterrows():
    common_tokens.update(text["text"].split())
common_tokens.most_common(10)
# Out:
# [('the', 4878),
#  ('and', 3669),
#  ('to', 3569),
#  ('I', 3182),
#  ('a', 3106),
#  (':', 2940),
#  ('of', 2899),
#  ('in', 2042),
#  ('notes', 2015),
#  ('is', 1750)]

# %%
common_tokens_list = []
for tup in common_tokens.most_common(1500):
    common_tokens_list.append(tup[0])
common_tokens_str = " ".join(common_tokens_list)
common_tokens_str[:30]
# Out:
# 'the and to I a : of in notes i'

# %%
# remove n most common tokens
common_tokens_list = common_tokens_list[500:]

# %%
common_res = get_keywords_from_uclassify_judging_classifer(common_tokens_str)
common_res
# Out:
# [[{'className': 'f', 'keyword': '13th', 'p': 0.651443},
#   {'className': 't', 'keyword': '●', 'p': 0.652034},
#   {'className': 't', 'keyword': '☂', 'p': 0.652428},
#   {'className': 'f', 'keyword': '►', 'p': 0.653902},
#   {'className': 'f', 'keyword': 'surnames', 'p': 0.654696},
#   {'className': 't', 'keyword': 'aoû', 'p': 0.718954},
#   {'className': 'f', 'keyword': 'grace', 'p': 0.655412},
#   {'className': 'f', 'keyword': '･', 'p': 0.758571},
#   {'className': 't', 'keyword': '2015', 'p': 0.710488},
#   {'className': 't', 'keyword': 'software', 'p': 0.676922},
#   {'className': 't', 'keyword': 'pee', 'p': 0.692516},
#   {'className': 't', 'keyword': '☩', 'p': 0.726374},
#   {'className': 'f', 'keyword': '✈', 'p': 0.800839},
#   {'className': 'f', 'keyword': '☁', 'p': 0.735535},
#   {'className': 't', 'keyword': '11th', 'p': 0.659531},
#   {'className': 't', 'keyword': '0803', 'p': 0.996689},
#   {'className': 't', 'keyword': '—i', 'p': 0.862141},
#   {'className': 'f', 'keyword': '±', 'p': 0.931917},
#   {'className': 't', 'keyword': '↲', 'p': 0.930315},
#   {'className': 't', 'keyword': 'pooped', 'p': 0.915204},
#   {'className': 't', 'keyword': 'nov', 'p': 0.757276},
#   {'className': 'f', 'keyword': 'gaza', 'p': 0.713557},
#   {'className': 'f', 'keyword': 'jaegerhugs', 'p': 0.997569},
#   {'className': 't', 'keyword': 'dec', 'p': 0.861116},
#   {'className': 't', 'keyword': '↱', 'p': 0.996689},
#   {'className': 't', 'keyword': '✪', 'p': 0.894408},
#   {'className': 't', 'keyword': 'kuroh', 'p': 0.954545},
#   {'className': 'f', 'keyword': 'zionism', 'p': 0.994896},
#   {'className': 't', 'keyword': 'epalry', 'p': 0.997238},
#   {'className': 't', 'keyword': 'argument', 'p': 0.663262}]]

# %%
common_kw = pd.DataFrame(common_res[0])
common_tDf = common_kw[common_kw.className == "t"]
common_fDf = common_kw[common_kw.className == "f"]
common_kw.className.value_counts()
# Out:
# t    19
# f    11
# Name: className, dtype: int64

# %%
common_tDf
# Out:
#    className   keyword         p
# 1          t         ●  0.652034
# 2          t         ☂  0.652428
# 5          t       aoû  0.718954
# 8          t      2015  0.710488
# 9          t  software  0.676922
# 10         t       pee  0.692516
# 11         t         ☩  0.726374
# 14         t      11th  0.659531
# 15         t      0803  0.996689
# 16         t        —i  0.862141
# 18         t         ↲  0.930315
# 19         t    pooped  0.915204
# 20         t       nov  0.757276
# 23         t       dec  0.861116
# 24         t         ↱  0.996689
# 25         t         ✪  0.894408
# 26         t     kuroh  0.954545
# 28         t    epalry  0.997238
# 29         t  argument  0.663262

# %%
common_fDf
# Out:
#    className     keyword         p
# 0          f        13th  0.651443
# 3          f           ►  0.653902
# 4          f    surnames  0.654696
# 6          f       grace  0.655412
# 7          f           ･  0.758571
# 12         f           ✈  0.800839
# 13         f           ☁  0.735535
# 17         f           ±  0.931917
# 21         f        gaza  0.713557
# 22         f  jaegerhugs  0.997569
# 27         f     zionism  0.994896

# %% [markdown]
# # Inspect the 7300 classified words from 15 samples

# %%
df = pd.read_pickle("sntf_7300_sampled_words_classification_results_df.pickle")
df.head(5)
# Out:
#                     s         n         t         f
# !            0.500000  0.500000  0.500000  0.500000
# !!!          0.500000  0.500000  0.500000  0.500000
# !!!!!        0.500000  0.500000  0.500000  0.500000
# #            0.606613  0.393387  0.398213  0.601787
# #000<semic>  0.848930  0.151070  0.847797  0.152203

# %%
df.s.sort_values(ascending=False).head(20)
# Out:
# mmatsuokah            1.000000
# tomhazeldine          0.999999
# nosebleed             0.999999
# trolltina             0.999999
# 출처:                   0.999999
# kvotheunkvothe        0.999999
# Dhavernas             0.999998
# veinteunopilotas      0.999998
# shyghost              0.999998
# lucyheartfllia        0.999997
# watchmen…             0.999997
# giffing               0.999994
# ntonystark            0.999993
# postracialcomments    0.999993
# tolzmannia            0.999993
# kijikun               0.999993
# largecoin             0.999993
# jusblaz               0.999993
# #glasslip             0.999987
# jackbarakat           0.999987
# Name: s, dtype: float64

# %%
df.n.sort_values(ascending=False).head(20)
# Out:
# Secular        1.000000
# secular        1.000000
# 15-year-old    0.999999
# Voiceover.     0.999999
# Jennwith2ns    0.999999
# #sunggyu       0.999999
# wecansexy      0.999999
# Rescuing       0.999998
# knickers       0.999997
# Buechner.      0.999997
# Buechner       0.999997
# Shusterman     0.999997
# freudian       0.999995
# h-a-r-p-o      0.999995
# re-visit       0.999995
# #myungsoo      0.999993
# bonkers.       0.999993
# Rarasaur       0.999993
# agnostics,     0.999993
# get,           0.999991
# Name: n, dtype: float64

# %%
df.t.sort_values(ascending=False).head(20)
# Out:
# DERSITE                 1.000000
# #nozaki                 0.999999
# Nobodies.               0.999998
# artalias                0.999998
# sagging                 0.999998
# antichamber             0.999996
# saeto15                 0.999995
# i-killed-your-senpai    0.999995
# kiekstn                 0.999995
# valvrave                0.999993
# Valvrave                0.999993
# Jacobin                 0.999991
# bakandroids             0.999990
# taliabobalia            0.999990
# guertena-art-museum     0.999990
# brontosaurs             0.999978
# brontosaurus,           0.999978
# mcstump                 0.999970
# arquius                 0.999970
# hoes”                   0.999970
# Name: t, dtype: float64

# %%
df.f.sort_values(ascending=False).head(20)
# Out:
# Jennwith2ns           0.999999
# anondracomalfoy       0.999999
# its-hipster-alpaca    0.999999
# tw<semic>             0.999998
# karahkan              0.999998
# Grendel               0.999997
# Buechner              0.999997
# Buechner.             0.999997
# three’s               0.999997
# Waltzing              0.999997
# doubtless             0.999996
# unwound.              0.999996
# onac911               0.999996
# #dongwoo              0.999992
# aswechoke             0.999992
# Galoshes)             0.999992
# ntonystark            0.999992
# starrlesscity         0.999992
# avpm/avps/avpsy       0.999992
# Galoshes              0.999992
# Name: f, dtype: float64
